# %% [markdown]
# # Michelin Rated Restaurants

# %%
import pandas as pd
# “Yes, I know down-casting won’t happen silently any more — I’m good with that!”
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ## Initial Exploration & Preparation of Data

# %%
michelin = pd.read_csv("../data/Michelin/michelin_data_2025.csv")
michelin.head(10)
# Out:
#                                              Name  \
# 0  Le Louis XV - Alain Ducasse à l'Hôtel de Paris
# 1                                     L'Ambroisie
# 2                                  Flocons de Sel
# 3                                         Épicure
# 4                                          Arpège
# 5                                  Le Pré Catelan
# 6                                         Le Cinq
# 7                                   Le Petit Nice
# 8                                             Kei
# 9                          L'Oustau de Baumanière
#
#                                              Address  \
# 0             Place du Casino, Monaco, 98000, France
# 1           9 place des Vosges, Paris, 75004, France
# 2  1775 route du Leutaz, Le Leutaz, Megève, 74120...
# 3  Le Bristol, 112 rue du Faubourg-Saint-Honoré, ...
# 4            84 rue de Varenne, Paris, 75007, France
# 5  Route de Suresnes - bois de Boulogne, Paris, 7...
# 6  Four Seasons Hotel George V, 31 avenue George-...
# 7         Anse de Maldormé, Marseille, 13007, France
# 8           5 rue du Coq-Héron, Paris, 75001, France
# 9  Mas de Baumanière, Les Baux-de-Provence, 13520...
#
#                        Location Price                                Cuisine  \
# 0                Monaco, France  €€€€  Mediterranean Cuisine, Modern Cuisine
# 1                 Paris, France  €€€€                        Classic Cuisine
# 2                Megève, France  €€€€                         Modern Cuisine
# 3                 Paris, France  €€€€                         Modern Cuisine
# 4                 Paris, France  €€€€                               Creative
# 5                 Paris, France  €€€€                 Creative, Contemporary
# 6                 Paris, France  €€€€                         Modern Cuisine
# 7             Marseille, France  €€€€                                Seafood
# 8                 Paris, France  €€€€               Modern Cuisine, Creative
# 9  Les Baux-de-Provence, France  €€€€                               Creative
#
#    Longitude   Latitude   PhoneNumber  \
# 0   7.427105  43.739184  3.779807e+10
# 1   2.364521  48.855494  3.314279e+10
# 2   6.596963  45.830240  3.345021e+10
# 3   2.314598  48.871722  3.315343e+10
# 4   2.317013  48.855754  3.314705e+10
# 5   2.250718  48.863937  3.314414e+10
# 6   2.300861  48.868760  3.314953e+10
# 7   5.352048  43.280257  3.349159e+10
# 8   2.342285  48.864395  3.314233e+10
# 9   4.787363  43.740266  3.349054e+10
#
#                                                  Url  \
# 0  https://guide.michelin.com/en/monaco-region/mo...
# 1  https://guide.michelin.com/en/ile-de-france/pa...
# 2  https://guide.michelin.com/en/auvergne-rhone-a...
# 3  https://guide.michelin.com/en/ile-de-france/pa...
# 4  https://guide.michelin.com/en/ile-de-france/pa...
# 5  https://guide.michelin.com/en/ile-de-france/pa...
# 6  https://guide.michelin.com/en/ile-de-france/pa...
# 7  https://guide.michelin.com/en/provence-alpes-c...
# 8  https://guide.michelin.com/en/ile-de-france/pa...
# 9  https://guide.michelin.com/en/provence-alpes-c...
#
#                                           WebsiteUrl    Award  GreenStar  \
# 0                     https://www.ducasse-paris.com/  3 Stars          0
# 1                   https://www.ambroisie-paris.com/  3 Stars          0
# 2                       https://www.floconsdesel.com  3 Stars          0
# 3  https://www.oetkercollection.com/fr/hotels/le-...  3 Stars          0
# 4                     https://www.alain-passard.com/  3 Stars          1
# 5                      https://www.leprecatelan.com/  3 Stars          0
# 6                        https://www.fourseasons.com  3 Stars          0
# 7                            https://www.passedat.fr  3 Stars          0
# 8                     https://www.restaurant-kei.fr/  3 Stars          0
# 9                          http://www.baumaniere.com  3 Stars          1
#
#                                FacilitiesAndServices  \
# 0  Air conditioning,Interesting wine list,Restaur...
# 1  Air conditioning,Restaurant offering vegetaria...
# 2  Car park,Garden or park,Great view,Interesting...
# 3  Air conditioning,Interesting wine list,Restaur...
# 4  Air conditioning,Interesting wine list,Restaur...
# 5  Air conditioning,Car park,Garden or park,Inter...
# 6  Air conditioning,Interesting wine list,Restaur...
# 7  Air conditioning,Car park,Great view,Interesti...
# 8             Air conditioning,Interesting wine list
# 9  Air conditioning,Car park,Garden or park,Great...
#
#                                          Description
# 0  It is difficult to present the Louis XV withou...
# 1  What to say of the creations of Bernard Pacaud...
# 2  (Temporarily closed, reopening planned for sec...
# 3  The Bristol is the quintessence of luxury from...
# 4  "The best cookbook ever written was by Mother ...
# 5  How time flies! Frédéric Anton has been the ch...
# 6  Unadulterated style and opulence - lofty colum...
# 7  Le Petit Nice is inextricably linked to the ci...
# 8  Kei for Kei Kobayashi, a chef born in Nagano, ...
# 9  A tremendous ambassador of the Mediterranean a...

# %%
print(f"Columns:\n{michelin.columns.to_list()}")
# Out:
# Columns:
# ['Name', 'Address', 'Location', 'Price', 'Cuisine', 'Longitude', 'Latitude', 'PhoneNumber', 'Url', 'WebsiteUrl', 'Award', 'GreenStar', 'FacilitiesAndServices', 'Description']

# %% [markdown]
# We aim to plot the coordinates on a map and search for population density correlation and compare UK and France.
#
# We drop `Url`, `PhoneNumber` and `FacilitiesAndService`. `Url` could perhaps become useful

# %%
michelin = michelin[['Name', 'Address', 'Location', 'Price', 'Cuisine', 'WebsiteUrl', 'Award', 'GreenStar', 'Longitude', 'Latitude']]
michelin.head()
# Out:
#                                              Name  \
# 0  Le Louis XV - Alain Ducasse à l'Hôtel de Paris
# 1                                     L'Ambroisie
# 2                                  Flocons de Sel
# 3                                         Épicure
# 4                                          Arpège
#
#                                              Address        Location Price  \
# 0             Place du Casino, Monaco, 98000, France  Monaco, France  €€€€
# 1           9 place des Vosges, Paris, 75004, France   Paris, France  €€€€
# 2  1775 route du Leutaz, Le Leutaz, Megève, 74120...  Megève, France  €€€€
# 3  Le Bristol, 112 rue du Faubourg-Saint-Honoré, ...   Paris, France  €€€€
# 4            84 rue de Varenne, Paris, 75007, France   Paris, France  €€€€
#
#                                  Cuisine  \
# 0  Mediterranean Cuisine, Modern Cuisine
# 1                        Classic Cuisine
# 2                         Modern Cuisine
# 3                         Modern Cuisine
# 4                               Creative
#
#                                           WebsiteUrl    Award  GreenStar  \
# 0                     https://www.ducasse-paris.com/  3 Stars          0
# 1                   https://www.ambroisie-paris.com/  3 Stars          0
# 2                       https://www.floconsdesel.com  3 Stars          0
# 3  https://www.oetkercollection.com/fr/hotels/le-...  3 Stars          0
# 4                     https://www.alain-passard.com/  3 Stars          1
#
#    Longitude   Latitude
# 0   7.427105  43.739184
# 1   2.364521  48.855494
# 2   6.596963  45.830240
# 3   2.314598  48.871722
# 4   2.317013  48.855754

# %%
# Columns are converted to lowercase for convenience
michelin.columns = michelin.columns.str.lower()

# %%
michelin.rename({'websiteurl': 'url'}, axis=1, inplace=True)
print(f"Columns:\n{michelin.columns.tolist()}")
# Out:
# Columns:
# ['name', 'address', 'location', 'price', 'cuisine', 'url', 'award', 'greenstar', 'longitude', 'latitude']

# %%
michelin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17735 entries, 0 to 17734
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       17735 non-null  object
#  1   address    17735 non-null  object
#  2   location   17735 non-null  object
#  3   price      17735 non-null  object
#  4   cuisine    17735 non-null  object
#  5   url        15248 non-null  object
#  6   award      17735 non-null  object
#  7   greenstar  17735 non-null  int64
#  8   longitude  17735 non-null  float64
#  9   latitude   17735 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# There exist missing values which will be dealt with once partitioned by location

# %% [markdown]
# Range of values for specific columns

# %%
ignore = ['longitude', 'latitude', 'url', 'cuisine']

for column in michelin:
    if column in ignore:
        pass
    else:
        print(f"\nUnique {column}s: {michelin[column].unique()}\nTotal Unique: {len(michelin[column].unique())} values")
# Out:
# Unique names: ["Le Louis XV - Alain Ducasse à l'Hôtel de Paris" "L'Ambroisie"
#  'Flocons de Sel' ... 'Kampa Park' 'Bockem' 'Aromi']
# Total Unique: 17068 values
#
# Unique addresss: ['Place du Casino, Monaco, 98000, France'
#  '9 place des Vosges, Paris, 75004, France'
#  '1775 route du Leutaz, Le Leutaz, Megève, 74120, France' ...
#  'Elišky Krásnohorské 2, Prague, 110 00, Czechia'
#  'Elišky Peškové 1095/5, Prague, 150 00, Czech Republic'
#  'Námĕstí Míru 6, Prague, 120 00, Czech Republic']
# Total Unique: 17323 values
#
# Unique locations: ['Monaco, France' 'Paris, France' 'Megève, France' ...
#  'Saint-Médard, Belgium' 'Wommelgem, Belgium' 'Tarcal, Hungary']
# Total Unique: 5794 values
#
# Unique prices: ['€€€€' '€€' '€€€' '¥¥¥¥' '¥¥¥' '$$$$' '$$$' '₩₩₩₩' '££££' '฿฿฿฿' '$$'
#  '₺₺₺₺' '¥¥' '₩₩₩' '₩₩' '£££' '﷼﷼﷼﷼' '﷼﷼﷼' '₺₺' '₺₺₺' '฿฿฿' '฿฿' '₫₫₫₫'
#  '₫₫' '$' '€' '¥' '₩' '££' '£' '﷼' '﷼﷼' '₺' '฿' '₫' '₫₫₫']
# Total Unique: 36 values
#
# Unique awards: ['3 Stars' 'Bib Gourmand' 'Selected Restaurants' '2 Stars' '1 Star']
# Total Unique: 5 values
#
# Unique greenstars: [0 1]
# Total Unique: 2 values

# %% [markdown]
# ----
# &nbsp;
# ## Separate `location` column
#
# - `country` column. eg, 'USA'
# - `city` column. eg, 'San Fransisco'
#
# `location` is comma separated "country, city"

# %%
# Are there non-comma separated entries in `location`?
no_comma = michelin[~michelin['location'].str.contains(',')]
no_comma['location'].unique().tolist()
# Out:
# ['Macau', 'Singapore', 'Dubai', 'Hong Kong', 'Abu Dhabi', 'Luxembourg']

# %% [markdown]
# These are all 'city states' or principalities.

# %%
# Create a dictionary for special cases
special_cases = {'Hong Kong': 'Hong Kong, Hong Kong SAR China',
                 'Macau': 'Macau, Macau SAR China',
                 'Singapore': 'Singapore, Singapore',
                 'Dubai': 'Dubai, United Arab Emirates',
                 'Luxembourg': 'Luxembourg, Luxembourg',
                 'Abu Dhabi': 'Abu Dhabi, United Arab Emirates'}

# %%
# Apply special cases to the 'location' column
michelin['location'] = michelin['location'].replace(special_cases)

# Now split the 'location' column
locations = michelin['location'].str.split(',', expand=True)
locations.columns = ['city', 'country']

# Remove leading or trailing whitespace from 'city' and 'country' columns
locations['city'] = locations['city'].str.strip()
locations['country'] = locations['country'].str.strip()

# Replace the original 'location' column with the new 'country' and 'city' columns
michelin = michelin.drop('location', axis=1).join(locations)

# %%
print(f"New Columns: {michelin.columns.tolist()}")
# Out:
# New Columns: ['name', 'address', 'price', 'cuisine', 'url', 'award', 'greenstar', 'longitude', 'latitude', 'city', 'country']

# %%
print(f"Unique Countries: {michelin['country'].unique()}"
      f"\nTotal Unique = {len(michelin['country'].unique())} values")
# Out:
# Unique Countries: ['France' 'Japan' 'Hong Kong SAR China' 'Macau SAR China' 'South Korea'
#  'United Kingdom' 'Austria' 'USA' 'Thailand' 'Spain' 'China Mainland'
#  'Italy' 'Switzerland' 'Netherlands' 'Taiwan' 'Singapore' 'Slovenia'
#  'Sweden' 'Denmark' 'Norway' 'Germany' 'Belgium' 'Portugal' 'Malta'
#  'Ireland' 'Greece' 'Hungary' 'Türkiye' 'Malaysia' 'Canada'
#  'United Arab Emirates' 'Croatia' 'Poland' 'Finland' 'Estonia' 'Brazil'
#  'Mexico' 'Luxembourg' 'Argentina' 'Serbia' 'Qatar' 'Andorra' 'Latvia'
#  'Liechtenstein' 'Vietnam' 'Lithuania' 'Iceland' 'Czech Republic']
# Total Unique = 48 values

# %%
print(f"Unique Cities: {michelin['city'].unique()}"
      f"\nTotal Unique = {len(michelin['city'].unique())} values")
# Out:
# Unique Cities: ['Monaco' 'Paris' 'Megève' ... 'Destelbergen' 'Wommelgem' 'Tarcal']
# Total Unique = 5780 values

# %%
michelin = michelin[['name', 'address', 'city', 'country', 'price', 'cuisine', 'url', 'award', 'greenstar', 'longitude', 'latitude']]
michelin.head()
# Out:
#                                              name  \
# 0  Le Louis XV - Alain Ducasse à l'Hôtel de Paris
# 1                                     L'Ambroisie
# 2                                  Flocons de Sel
# 3                                         Épicure
# 4                                          Arpège
#
#                                              address    city country price  \
# 0             Place du Casino, Monaco, 98000, France  Monaco  France  €€€€
# 1           9 place des Vosges, Paris, 75004, France   Paris  France  €€€€
# 2  1775 route du Leutaz, Le Leutaz, Megève, 74120...  Megève  France  €€€€
# 3  Le Bristol, 112 rue du Faubourg-Saint-Honoré, ...   Paris  France  €€€€
# 4            84 rue de Varenne, Paris, 75007, France   Paris  France  €€€€
#
#                                  cuisine  \
# 0  Mediterranean Cuisine, Modern Cuisine
# 1                        Classic Cuisine
# 2                         Modern Cuisine
# 3                         Modern Cuisine
# 4                               Creative
#
#                                                  url    award  greenstar  \
# 0                     https://www.ducasse-paris.com/  3 Stars          0
# 1                   https://www.ambroisie-paris.com/  3 Stars          0
# 2                       https://www.floconsdesel.com  3 Stars          0
# 3  https://www.oetkercollection.com/fr/hotels/le-...  3 Stars          0
# 4                     https://www.alain-passard.com/  3 Stars          1
#
#    longitude   latitude
# 0   7.427105  43.739184
# 1   2.364521  48.855494
# 2   6.596963  45.830240
# 3   2.314598  48.871722
# 4   2.317013  48.855754

# %% [markdown]
# -----
# &nbsp;
# ### Count by country

# %%
pivot_table = michelin.pivot_table(index='country', columns=['award'], aggfunc='size', fill_value=0)
pivot_table
# Out:
# award                 1 Star  2 Stars  3 Stars  Bib Gourmand  \
# country
# Andorra                    1        0        0             0
# Argentina                  6        1        0             7
# Austria                   62       18        2            43
# Belgium                  111       20        2           124
# Brazil                    15        6        0            36
# Canada                    25        1        0            37
# China Mainland           109       18        4           183
# Croatia                   10        1        0            11
# Czech Republic             2        0        0             4
# Denmark                   21        7        3            18
# Estonia                    1        1        0             6
# Finland                    8        1        0             4
# France                   542       81       31           396
# Germany                  266       46       10           194
# Greece                    11        1        0             6
# Hong Kong SAR China       58       11        7            65
# Hungary                    8        2        0            11
# Iceland                    3        0        0             0
# Ireland                   16        5        0            18
# Italy                    333       38       14           248
# Japan                    286       56       20           236
# Latvia                     2        0        0             3
# Liechtenstein              1        0        0             0
# Lithuania                  4        0        0             4
# Luxembourg                 7        1        0             4
# Macau SAR China           11        6        2            11
# Malaysia                   6        1        0            56
# Malta                      6        1        0             5
# Mexico                    16        2        0            42
# Netherlands              101       19        1            82
# Norway                    17        1        2             4
# Poland                     5        1        0            16
# Portugal                  38        8        0            28
# Qatar                      2        0        0             4
# Serbia                     2        0        0             2
# Singapore                 38        6        3            80
# Slovenia                   8        1        1            10
# South Korea               30        9        1            77
# Spain                    239       32       16           213
# Sweden                    17        4        1            11
# Switzerland              101       25        4           113
# Taiwan                    41        4        3           126
# Thailand                  28        7        1           156
# Türkiye                   13        1        0            27
# USA                      213       32       14           381
# United Arab Emirates      18        4        0            25
# United Kingdom           164       23       10           130
# Vietnam                    7        0        0            58
#
# award                 Selected Restaurants
# country
# Andorra                                  5
# Argentina                               54
# Austria                                206
# Belgium                                504
# Brazil                                  80
# Canada                                 110
# China Mainland                         244
# Croatia                                 69
# Czech Republic                          18
# Denmark                                 48
# Estonia                                 27
# Finland                                 15
# France                                1951
# Germany                                757
# Greece                                  17
# Hong Kong SAR China                     65
# Hungary                                 57
# Iceland                                  5
# Ireland                                 63
# Italy                                 1350
# Japan                                  465
# Latvia                                  26
# Liechtenstein                            2
# Lithuania                               24
# Luxembourg                              39
# Macau SAR China                         24
# Malaysia                                80
# Malta                                   30
# Mexico                                  97
# Netherlands                            294
# Norway                                  26
# Poland                                  53
# Portugal                               116
# Qatar                                   27
# Serbia                                  19
# Singapore                              160
# Slovenia                                43
# South Korea                            117
# Spain                                  752
# Sweden                                  41
# Switzerland                            296
# Taiwan                                 179
# Thailand                               269
# Türkiye                                 90
# USA                                    914
# United Arab Emirates                   103
# United Kingdom                         707
# Vietnam                                 99

# %%
michelin_filtered = michelin[michelin['award'] != 'Bib Gourmand']
pivot_table_filtered = michelin_filtered.pivot_table(index='country', columns='award', aggfunc='size', fill_value=0)
pivot_table_filtered['total_ratings'] = pivot_table_filtered.sum(axis=1)

# Rank the countries based on the total ratings
pivot_table_filtered['rank'] = pivot_table_filtered['total_ratings'].rank(ascending=False)
pivot_table_sorted = pivot_table_filtered.sort_values(by='rank')
pivot_table_sorted
# Out:
# award                 1 Star  2 Stars  3 Stars  Selected Restaurants  \
# country
# France                   542       81       31                  1951
# Italy                    333       38       14                  1350
# USA                      213       32       14                   914
# Germany                  266       46       10                   757
# Spain                    239       32       16                   752
# United Kingdom           164       23       10                   707
# Japan                    286       56       20                   465
# Belgium                  111       20        2                   504
# Switzerland              101       25        4                   296
# Netherlands              101       19        1                   294
# China Mainland           109       18        4                   244
# Thailand                  28        7        1                   269
# Austria                   62       18        2                   206
# Taiwan                    41        4        3                   179
# Singapore                 38        6        3                   160
# Portugal                  38        8        0                   116
# South Korea               30        9        1                   117
# Hong Kong SAR China       58       11        7                    65
# Canada                    25        1        0                   110
# United Arab Emirates      18        4        0                   103
# Mexico                    16        2        0                    97
# Vietnam                    7        0        0                    99
# Türkiye                   13        1        0                    90
# Brazil                    15        6        0                    80
# Malaysia                   6        1        0                    80
# Ireland                   16        5        0                    63
# Croatia                   10        1        0                    69
# Denmark                   21        7        3                    48
# Hungary                    8        2        0                    57
# Sweden                    17        4        1                    41
# Argentina                  6        1        0                    54
# Poland                     5        1        0                    53
# Slovenia                   8        1        1                    43
# Luxembourg                 7        1        0                    39
# Norway                    17        1        2                    26
# Macau SAR China           11        6        2                    24
# Malta                      6        1        0                    30
# Greece                    11        1        0                    17
# Qatar                      2        0        0                    27
# Estonia                    1        1        0                    27
# Lithuania                  4        0        0                    24
# Latvia                     2        0        0                    26
# Finland                    8        1        0                    15
# Serbia                     2        0        0                    19
# Czech Republic             2        0        0                    18
# Iceland                    3        0        0                     5
# Andorra                    1        0        0                     5
# Liechtenstein              1        0        0                     2
#
# award                 total_ratings  rank
# country
# France                         2605   1.0
# Italy                          1735   2.0
# USA                            1173   3.0
# Germany                        1079   4.0
# Spain                          1039   5.0
# United Kingdom                  904   6.0
# Japan                           827   7.0
# Belgium                         637   8.0
# Switzerland                     426   9.0
# Netherlands                     415  10.0
# China Mainland                  375  11.0
# Thailand                        305  12.0
# Austria                         288  13.0
# Taiwan                          227  14.0
# Singapore                       207  15.0
# Portugal                        162  16.0
# South Korea                     157  17.0
# Hong Kong SAR China             141  18.0
# Canada                          136  19.0
# United Arab Emirates            125  20.0
# Mexico                          115  21.0
# Vietnam                         106  22.0
# Türkiye                         104  23.0
# Brazil                          101  24.0
# Malaysia                         87  25.0
# Ireland                          84  26.0
# Croatia                          80  27.0
# Denmark                          79  28.0
# Hungary                          67  29.0
# Sweden                           63  30.0
# Argentina                        61  31.0
# Poland                           59  32.0
# Slovenia                         53  33.0
# Luxembourg                       47  34.0
# Norway                           46  35.0
# Macau SAR China                  43  36.0
# Malta                            37  37.0
# Greece                           29  39.0
# Qatar                            29  39.0
# Estonia                          29  39.0
# Lithuania                        28  41.5
# Latvia                           28  41.5
# Finland                          24  43.0
# Serbia                           21  44.0
# Czech Republic                   20  45.0
# Iceland                           8  46.0
# Andorra                           6  47.0
# Liechtenstein                     3  48.0

# %%
# Filter out 'Bib Gourmand'
michelin_filtered = michelin[michelin['award'] != 'Bib Gourmand']

# Create a pivot table for the total number of star ratings
star_rating_pivot = michelin_filtered.pivot_table(index='award', aggfunc='size', fill_value=0)
star_rating_pivot.loc['Total'] = star_rating_pivot.sum()
star_rating_pivot
# Out:
# award
# 1 Star                   3029
# 2 Stars                   502
# 3 Stars                   152
# Selected Restaurants    10737
# Total                   14420
# dtype: int64

# %% [markdown]
# ----
#
# ## `awards` columns
#
# In the Michelin dataset, we have a column named 'awards' that designates the level of recognition a restaurant has achieved according to Michelin's rating system. These awards are '3 Stars', '2 Stars', '1 Star', and 'Bib Gourmand', which is a different award for good quality, good value restaurants.
#
# However, in order to make the analysis more tractable and to create a more uniform scale, we transform these awards into numerical values. This transformation will allow us to perform quantitative analysis and make mathematical computations with this data, which wouldn't be possible with the original textual data.
#
# The '3 MICHELIN Stars', '2 MICHELIN Stars', and '1 MICHELIN Star' awards are straightforwardly transformed into the numerical values 3, 2, and 1, respectively. However, the 'Bib Gourmand' award doesn't fit directly into this star system. In consideration of the prestige and value attached to this award, we've decided to map 'Bib Gourmand' to the value 0.5. It's important to note that this decision, while somewhat arbitrary, is made with the understanding that the 'Bib Gourmand' recognizes a different aspect of restaurant quality and is not strictly comparable to the star awards.

# %%
award_dict = {'3 Stars': 3, '2 Stars': 2, '1 Star': 1, 'Bib Gourmand': 0.5, 'Selected Restaurants': 0.25}
michelin['stars'] = michelin['award'].replace(award_dict).infer_objects(copy=False).astype(float)

# %%
cols = michelin.columns.tolist()

cols.remove('stars')
# insert 'stars' at the desired position next to 'award' which we retain
cols.insert(-2, 'stars')

# reindex the DataFrame
michelin = michelin.reindex(columns=cols)

# %%
michelin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17735 entries, 0 to 17734
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       17735 non-null  object
#  1   address    17735 non-null  object
#  2   city       17735 non-null  object
#  3   country    17735 non-null  object
#  4   price      17735 non-null  object
#  5   cuisine    17735 non-null  object
#  6   url        15248 non-null  object
#  7   award      17735 non-null  object
#  8   greenstar  17735 non-null  int64
#  9   stars      17735 non-null  float64
#  10  longitude  17735 non-null  float64
#  11  latitude   17735 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.6+ MB

# %% [markdown]
# ----
# &nbsp;
# ## `price` column
#
# There is also the price column to organise which lists a number of different currencies. It is unclear if, for example, $ refers to USD, HKD etc..
#
# This attribute is easier to deal with piecewise by country

# %% [markdown]
# ----
# &nbsp;
# ## Export `UK` and `France` datasets for further analysis

# %%
# Filter the DataFrame for records where country == 'UK'
uk_data = michelin[michelin['country'] == 'United Kingdom']
uk_data.head()
# Out:
#                                name  \
# 51                        L'Enclume
# 52  Alain Ducasse at The Dorchester
# 53  Hélène Darroze at The Connaught
# 54         Restaurant Gordon Ramsay
# 55                         Fat Duck
#
#                                               address     city  \
# 51  Cavendish Street, Cartmel, LA11 6QA, United Ki...  Cartmel
# 52  Park Lane, Mayfair, London, W1K 1QA, United Ki...   London
# 53  Carlos Place, Mayfair, London, W1K 2AL, United...   London
# 54  68-69 Royal Hospital Road, Chelsea, London, SW...   London
# 55         High Street, Bray, SL6 2AQ, United Kingdom     Bray
#
#            country price           cuisine  \
# 51  United Kingdom  ££££  Creative British
# 52  United Kingdom  ££££            French
# 53  United Kingdom  ££££    Modern Cuisine
# 54  United Kingdom  ££££            French
# 55  United Kingdom  ££££          Creative
#
#                                                   url    award  greenstar  \
# 51                        https://www.lenclume.co.uk/  3 Stars          1
# 52           https://www.alainducasse-dorchester.com/  3 Stars          0
# 53  https://www.the-connaught.co.uk/restaurants-ba...  3 Stars          0
# 54  https://www.gordonramsayrestaurants.com/restau...  3 Stars          0
# 55                          https://thefatduck.co.uk/  3 Stars          0
#
#     stars  longitude   latitude
# 51    3.0  -2.953868  54.201771
# 52    3.0  -0.152575  51.507338
# 53    3.0  -0.149290  51.510188
# 54    3.0  -0.162177  51.485438
# 55    3.0  -0.701753  51.507858

# %%
# Export the UK data to a csv file
uk_data.to_csv('../data/UK/uk_data_2025.csv', index=False)

# %%
# Filter the DataFrame for records where country == 'France'
france_data = michelin[michelin['country'] == 'France']
france_data.head()
# Out:
#                                              name  \
# 0  Le Louis XV - Alain Ducasse à l'Hôtel de Paris
# 1                                     L'Ambroisie
# 2                                  Flocons de Sel
# 3                                         Épicure
# 4                                          Arpège
#
#                                              address    city country price  \
# 0             Place du Casino, Monaco, 98000, France  Monaco  France  €€€€
# 1           9 place des Vosges, Paris, 75004, France   Paris  France  €€€€
# 2  1775 route du Leutaz, Le Leutaz, Megève, 74120...  Megève  France  €€€€
# 3  Le Bristol, 112 rue du Faubourg-Saint-Honoré, ...   Paris  France  €€€€
# 4            84 rue de Varenne, Paris, 75007, France   Paris  France  €€€€
#
#                                  cuisine  \
# 0  Mediterranean Cuisine, Modern Cuisine
# 1                        Classic Cuisine
# 2                         Modern Cuisine
# 3                         Modern Cuisine
# 4                               Creative
#
#                                                  url    award  greenstar  \
# 0                     https://www.ducasse-paris.com/  3 Stars          0
# 1                   https://www.ambroisie-paris.com/  3 Stars          0
# 2                       https://www.floconsdesel.com  3 Stars          0
# 3  https://www.oetkercollection.com/fr/hotels/le-...  3 Stars          0
# 4                     https://www.alain-passard.com/  3 Stars          1
#
#    stars  longitude   latitude
# 0    3.0   7.427105  43.739184
# 1    3.0   2.364521  48.855494
# 2    3.0   6.596963  45.830240
# 3    3.0   2.314598  48.871722
# 4    3.0   2.317013  48.855754

# %%
# Define and export Monaco
monaco = france_data[france_data['city'] == 'Monaco']
monaco.to_csv('../data/France/monaco_2025.csv', index=False)

# %% [markdown]
# We remove Monaco from metropolitan France

# %%
france_data = france_data[france_data['city'] != 'Monaco']
france_data.shape
# Out:
# (2985, 12)

# %%
# Export the France data to a csv file
france_data.to_csv('../data/France/france_master_2025.csv', index=False)

# %% [markdown]
# ----
# &nbsp;
# ## Restaurants could be further partitioned by country from this point
