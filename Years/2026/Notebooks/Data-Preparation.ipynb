# %% [markdown]
# # Michelin Rated Restaurants

# %%
import pandas as pd
# “Yes, I know down-casting won’t happen silently any more — I’m good with that!”
pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# ## Initial Exploration & Preparation of Data

# %%
michelin = pd.read_csv("../data/Michelin/michelin_data_2026.csv")
michelin.head(10)
# Out:
#                                     Name  \
# 0                                ES:SENZ
# 1               Tohru in der Schreiberei
# 2                       Schwarzwaldstube
# 3  Victor's Fine Dining by christian bau
# 4                    schanz. restaurant.
# 5                     Restaurant Haerlin
# 6                The Table Kevin Fehling
# 7                      Waldhotel Sonnora
# 8                                    JAN
# 9                     Restaurant Bareiss
#
#                                              Address              Location  \
# 0     Mietenkamer Straße 65, Grassau, 83224, Germany      Grassau, Germany
# 1               Burgstraße 5, Munich, 80331, Germany       Munich, Germany
# 2     Tonbachstraße 237, Baiersbronn, 72270, Germany  Baiersbronn, Germany
# 3             Schlossstraße 27, Perl, 66706, Germany         Perl, Germany
# 4         Bahnhofstraße 8a, Piesport, 54498, Germany     Piesport, Germany
# 5     Neuer Jungfernstieg 9, Hamburg, 20354, Germany      Hamburg, Germany
# 6          Shanghaiallee 15, Hamburg, 20457, Germany      Hamburg, Germany
# 7          Auf'm Eichelfeld 1, Dreis, 54518, Germany        Dreis, Germany
# 8            Luisenstraße 27, Munich, 80333, Germany       Munich, Germany
# 9  Hermine-Bareiss-Weg 1, Baiersbronn, 72270, Ger...  Baiersbronn, Germany
#
#   Price                                Cuisine  Longitude   Latitude  \
# 0  €€€€               Creative, Modern Cuisine  12.465618  47.785630
# 1  €€€€  Modern Cuisine, Japanese Contemporary  11.577475  48.137597
# 2  €€€€               Classic French, Creative   8.358280  48.536911
# 3  €€€€                 Creative, Contemporary   6.387211  49.535173
# 4  €€€€                Modern French, Creative   6.926600  49.877600
# 5  €€€€       Creative French, Classic Cuisine   9.991464  53.555442
# 6  €€€€                Creative, International  10.003073  53.542486
# 7  €€€€                         Classic French   6.810934  49.937732
# 8  €€€€               Creative, Modern Cuisine  11.562988  48.144798
# 9  €€€€       Classic French, Seasonal Cuisine   8.326825  48.520132
#
#     PhoneNumber                                                Url  \
# 0  4.986414e+11  https://guide.michelin.com/en/bayern/grassau/r...
# 1  4.989215e+11  https://guide.michelin.com/en/bayern/mnchen/re...
# 2  4.974425e+11  https://guide.michelin.com/en/baden-wurttember...
# 3  4.968668e+10  https://guide.michelin.com/en/saarland/perl/re...
# 4  4.965079e+10  https://guide.michelin.com/en/rheinland-pfalz/...
# 5  4.940349e+08  https://guide.michelin.com/en/hamburg-region/h...
# 6  4.940229e+11  https://guide.michelin.com/en/hamburg-region/h...
# 7  4.965790e+10  https://guide.michelin.com/en/rheinland-pfalz/...
# 8  4.989237e+11  https://guide.michelin.com/en/bayern/mnchen/re...
# 9  4.974425e+08  https://guide.michelin.com/en/baden-wurttember...
#
#                                           WebsiteUrl    Award  GreenStar  \
# 0                https://www.das-achental.com/essenz  3 Stars          0
# 1                        https://schreiberei-muc.de/  3 Stars          0
# 2  https://www.traube-tonbach.de/kulinarik/schwar...  3 Stars          0
# 3                https://www.victors-fine-dining.de/  3 Stars          0
# 4               https://www.schanz-restaurant.de/de/  3 Stars          0
# 5                  https://restaurant-haerlin.de/de/  3 Stars          0
# 6                       https://thetable-hamburg.de/  3 Stars          0
# 7                      https://www.hotel-sonnora.de/  3 Stars          0
# 8                           https://jan-hartwig.com/  3 Stars          0
# 9                           https://www.bareiss.com/  3 Stars          0
#
#                                FacilitiesAndServices  \
# 0    Air conditioning,Car park,Interesting wine list
# 1            Interesting wine list,Notable sake list
# 2  Air conditioning,Car park,Great view,Interesti...
# 3  Air conditioning,Car park,Interesting wine lis...
# 4        Air conditioning,Car park,Wheelchair access
# 5  Air conditioning,Great view,Interesting wine l...
# 6                    Air conditioning,Counter dining
# 7      Car park,Garden or park,Interesting wine list
# 8                              Interesting wine list
# 9  Air conditioning,Car park,Interesting wine lis...
#
#                                          Description
# 0  From the get-go, the stage is set in grand sty...
# 1  It is absolutely worth climbing the 23 steps o...
# 2  Schwarzwaldstube, the flagship restaurant of t...
# 3  The way in which Christian Bau combines influe...
# 4  It is thanks to Thomas Schanz that this small ...
# 5  One of Hamburg's classic hotels, the legendary...
# 6  In his set menu (dubbed "Das Tor zur Welt" – "...
# 7  This legendary fine dining establishment has a...
# 8  This restaurant has firmly established itself ...
# 9  Claus-Peter Lumpp has been head chef at the fi...

# %%
print(f"Columns:\n{michelin.columns.to_list()}")
# Out:
# Columns:
# ['Name', 'Address', 'Location', 'Price', 'Cuisine', 'Longitude', 'Latitude', 'PhoneNumber', 'Url', 'WebsiteUrl', 'Award', 'GreenStar', 'FacilitiesAndServices', 'Description']

# %% [markdown]
# We aim to plot the coordinates on a map and search for population density correlation and compare UK and France.
#
# We drop `Url`, `PhoneNumber` and `FacilitiesAndService`. `Url` could perhaps become useful

# %%
michelin = michelin[['Name', 'Address', 'Location', 'Price', 'Cuisine', 'WebsiteUrl', 'Award', 'GreenStar', 'Longitude', 'Latitude']]
michelin.head()
# Out:
#                                     Name  \
# 0                                ES:SENZ
# 1               Tohru in der Schreiberei
# 2                       Schwarzwaldstube
# 3  Victor's Fine Dining by christian bau
# 4                    schanz. restaurant.
#
#                                           Address              Location Price  \
# 0  Mietenkamer Straße 65, Grassau, 83224, Germany      Grassau, Germany  €€€€
# 1            Burgstraße 5, Munich, 80331, Germany       Munich, Germany  €€€€
# 2  Tonbachstraße 237, Baiersbronn, 72270, Germany  Baiersbronn, Germany  €€€€
# 3          Schlossstraße 27, Perl, 66706, Germany         Perl, Germany  €€€€
# 4      Bahnhofstraße 8a, Piesport, 54498, Germany     Piesport, Germany  €€€€
#
#                                  Cuisine  \
# 0               Creative, Modern Cuisine
# 1  Modern Cuisine, Japanese Contemporary
# 2               Classic French, Creative
# 3                 Creative, Contemporary
# 4                Modern French, Creative
#
#                                           WebsiteUrl    Award  GreenStar  \
# 0                https://www.das-achental.com/essenz  3 Stars          0
# 1                        https://schreiberei-muc.de/  3 Stars          0
# 2  https://www.traube-tonbach.de/kulinarik/schwar...  3 Stars          0
# 3                https://www.victors-fine-dining.de/  3 Stars          0
# 4               https://www.schanz-restaurant.de/de/  3 Stars          0
#
#    Longitude   Latitude
# 0  12.465618  47.785630
# 1  11.577475  48.137597
# 2   8.358280  48.536911
# 3   6.387211  49.535173
# 4   6.926600  49.877600

# %%
# Columns are converted to lowercase for convenience
michelin.columns = michelin.columns.str.lower()

# %%
michelin.rename({'websiteurl': 'url'}, axis=1, inplace=True)
print(f"Columns:\n{michelin.columns.tolist()}")
# Out:
# Columns:
# ['name', 'address', 'location', 'price', 'cuisine', 'url', 'award', 'greenstar', 'longitude', 'latitude']

# %%
michelin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18908 entries, 0 to 18907
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       18908 non-null  object
#  1   address    18908 non-null  object
#  2   location   18908 non-null  object
#  3   price      18908 non-null  object
#  4   cuisine    18908 non-null  object
#  5   url        16189 non-null  object
#  6   award      18908 non-null  object
#  7   greenstar  18908 non-null  int64
#  8   longitude  18908 non-null  float64
#  9   latitude   18908 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# There exist missing values which will be dealt with once partitioned by location

# %% [markdown]
# Range of values for specific columns

# %%
ignore = ['longitude', 'latitude', 'url', 'cuisine']

for column in michelin:
    if column in ignore:
        pass
    else:
        print(f"\nUnique {column}s: {michelin[column].unique()}\nTotal Unique: {len(michelin[column].unique())} values")
# Out:
# Unique names: ['ES:SENZ' 'Tohru in der Schreiberei' 'Schwarzwaldstube' ... 'Gustificio'
#  'Inka' 'Casa Celesia']
# Total Unique: 18213 values
#
# Unique addresss: ['Mietenkamer Straße 65, Grassau, 83224, Germany'
#  'Burgstraße 5, Munich, 80331, Germany'
#  'Tonbachstraße 237, Baiersbronn, 72270, Germany' ...
#  'Via Guglielmo Marconi 36, Carmignano di Brenta, 35010, Italy'
#  'via Guglielmo Oberdan 18/A, Verona, 37121, Italy'
#  'Piazza Martiri della Libertà, 31, Oleggio, 28047, Italy']
# Total Unique: 18451 values
#
# Unique locations: ['Grassau, Germany' 'Munich, Germany' 'Baiersbronn, Germany' ...
#  'Ponte de Lima, Portugal' 'Carmignano di Brenta, Italy' 'Oleggio, Italy']
# Total Unique: 6013 values
#
# Unique prices: ['€€€€' '$$$$' '€€€' '€€' '¥¥¥¥' '¥¥¥' '₫₫₫₫' '₫₫₫' '₫₫' '$' '$$$' '$$'
#  '¥¥' '€' '₫' '¥' '฿฿' '฿฿฿' '฿' '₺₺' '₺₺₺' '฿฿฿฿' '₺₺₺₺' '﷼﷼﷼﷼' '﷼﷼﷼' '﷼'
#  '﷼﷼' '₺' '₩₩₩' '₩' '₩₩' '£££' '££££' '££' '£' '₩₩₩₩']
# Total Unique: 36 values
#
# Unique awards: ['3 Stars' 'Selected Restaurants' '1 Star' '2 Stars' 'Bib Gourmand']
# Total Unique: 5 values
#
# Unique greenstars: [0 1]
# Total Unique: 2 values

# %% [markdown]
# ----
# &nbsp;
# ## Separate `location` column
#
# - `country` column. eg, 'USA'
# - `city` column. eg, 'San Fransisco'
#
# `location` is comma separated "country, city"

# %%
# Are there non-comma separated entries in `location`?
no_comma = michelin[~michelin['location'].str.contains(',')]
no_comma['location'].unique().tolist()
# Out:
# ['Dubai', 'Luxembourg', 'Singapore', 'Abu Dhabi', 'Macau']

# %% [markdown]
# These are all 'city states' or principalities.

# %%
# Create a dictionary for special cases
special_cases = {'Hong Kong': 'Hong Kong, Hong Kong SAR China',
                 'Macau': 'Macau, Macau SAR China',
                 'Singapore': 'Singapore, Singapore',
                 'Dubai': 'Dubai, United Arab Emirates',
                 'Luxembourg': 'Luxembourg, Luxembourg',
                 'Abu Dhabi': 'Abu Dhabi, United Arab Emirates'}

# %% [markdown]
# US restaurants have been reformated

# %%
problem_locations = (
    michelin['location']
    .astype('string')
    [michelin['location'].astype('string').str.count(',') > 1]
    .dropna()
    .unique()
)

print(problem_locations)
print(f"Unique location values with more than one comma: {len(problem_locations)}")
# Out:
# <StringArray>
# [           'Miami, FL, USA',          'Orlando, FL, USA',
#   'Fort Lauderdale, FL, USA',            'Tampa, FL, USA',
#       'Miami Beach, FL, USA',     'Coral Gables, FL, USA',
#       'Winter Park, FL, USA',         'Surfside, FL, USA',
#   'West Palm Beach, FL, USA',    'Winter Garden, FL, USA',
#  ...
#             'Bronx, NY, USA',        'Peekskill, NY, USA',
#  'Long Island City, NY, USA',     'New Rochelle, NY, USA',
#       'Mount Kisco, NY, USA',          'Astoria, NY, USA',
#               'Rye, NY, USA',        'Hartsdale, NY, USA',
#        'Mamaroneck, NY, USA',    'West Harrison, NY, USA']
# Length: 244, dtype: string
# Unique location values with more than one comma: 244

# %%
# Apply special cases first
michelin['location'] = michelin['location'].replace(special_cases)

# Clean and normalize
loc = michelin['location'].str.strip()

# Split from the right into at most 3 parts:
# city | state | country
parts = loc.str.rsplit(',', n=2, expand=True)

# Guarantee 3 columns
for i in range(parts.shape[1], 3):
    parts[i] = pd.NA

# If only 2 parts exist, treat them as city + country
if parts.shape[1] >= 2:
    two_part_rows = parts[2].isna()
    parts.loc[two_part_rows, 2] = parts.loc[two_part_rows, 1]
    parts.loc[two_part_rows, 1] = pd.NA

parts.columns = ['city', 'state', 'country']

# Trim whitespace
for col in ['city', 'state', 'country']:
    parts[col] = parts[col].astype('string').str.strip()

# Replace original column
michelin = michelin.drop(columns=['location']).join(parts)

# %% [markdown]
# Legacy below

# %%
# # Apply special cases to the 'location' column
# michelin['location'] = michelin['location'].replace(special_cases)
#
# # Now split the 'location' column
# locations = michelin['location'].str.split(',', expand=True)
# locations.columns = ['city', 'country']
#
# # Remove leading or trailing whitespace from 'city' and 'country' columns
# locations['city'] = locations['city'].str.strip()
# locations['country'] = locations['country'].str.strip()
#
# # Replace the original 'location' column with the new 'country' and 'city' columns
# michelin = michelin.drop('location', axis=1).join(locations)

# %%
print(f"New Columns: {michelin.columns.tolist()}")
# Out:
# New Columns: ['name', 'address', 'price', 'cuisine', 'url', 'award', 'greenstar', 'longitude', 'latitude', 'city', 'state', 'country']

# %%
print(f"Unique Countries: {michelin['country'].unique()}"
      f"\nTotal Unique = {len(michelin['country'].unique())} values")
# Out:
# Unique Countries: <StringArray>
# [               'Germany',                 'Norway',                 'Sweden',
#                 'Denmark',               'Slovenia',   'United Arab Emirates',
#                 'Belgium',                  'Japan',                'Finland',
#                  'Poland',                 'Mexico',                 'Canada',
#                  'Brazil',       'Chinese Mainland',             'Luxembourg',
#                     'USA',              'Argentina',                 'Greece',
#                 'Iceland',                'Vietnam',              'Lithuania',
#                 'Estonia',                 'Taiwan',                  'Italy',
#                   'Spain',            'Switzerland',              'Singapore',
#                'Thailand',            'Netherlands',                'Croatia',
#                 'Türkiye',        'The Philippines',                'Hungary',
#                  'Latvia',          'Liechtenstein',           'Saudi Arabia',
#                'Malaysia',                'Andorra',                'Czechia',
#                  'Serbia',                  'Qatar',                'Austria',
#             'South Korea',         'United Kingdom',                'Ireland',
#                  'France',                  'Malta',    'Hong Kong SAR China',
#         'Macau SAR China', 'Principality of Monaco',               'Portugal']
# Length: 51, dtype: string
# Total Unique = 51 values

# %%
print(f"Unique Cities: {michelin['city'].unique()}"
      f"\nTotal Unique = {len(michelin['city'].unique())} values")
# Out:
# Unique Cities: <StringArray>
# [             'Grassau',               'Munich',          'Baiersbronn',
#                  'Perl',             'Piesport',              'Hamburg',
#                 'Dreis',               'Berlin',                 'Oslo',
#             'Stavanger',
#  ...
#               'Portela',            'Quarteira',           'Cantanhede',
#                 'Loulé',             'Odeceixe',   'Moreira de Cónegos',
#            'Matosinhos',        'Ponte de Lima', 'Carmignano di Brenta',
#               'Oleggio']
# Length: 5993, dtype: string
# Total Unique = 5993 values

# %%
michelin = michelin[['name', 'address', 'city', 'country', 'price', 'cuisine', 'url', 'award', 'greenstar', 'longitude', 'latitude']]
michelin.head()
# Out:
#                                     name  \
# 0                                ES:SENZ
# 1               Tohru in der Schreiberei
# 2                       Schwarzwaldstube
# 3  Victor's Fine Dining by christian bau
# 4                    schanz. restaurant.
#
#                                           address         city  country price  \
# 0  Mietenkamer Straße 65, Grassau, 83224, Germany      Grassau  Germany  €€€€
# 1            Burgstraße 5, Munich, 80331, Germany       Munich  Germany  €€€€
# 2  Tonbachstraße 237, Baiersbronn, 72270, Germany  Baiersbronn  Germany  €€€€
# 3          Schlossstraße 27, Perl, 66706, Germany         Perl  Germany  €€€€
# 4      Bahnhofstraße 8a, Piesport, 54498, Germany     Piesport  Germany  €€€€
#
#                                  cuisine  \
# 0               Creative, Modern Cuisine
# 1  Modern Cuisine, Japanese Contemporary
# 2               Classic French, Creative
# 3                 Creative, Contemporary
# 4                Modern French, Creative
#
#                                                  url    award  greenstar  \
# 0                https://www.das-achental.com/essenz  3 Stars          0
# 1                        https://schreiberei-muc.de/  3 Stars          0
# 2  https://www.traube-tonbach.de/kulinarik/schwar...  3 Stars          0
# 3                https://www.victors-fine-dining.de/  3 Stars          0
# 4               https://www.schanz-restaurant.de/de/  3 Stars          0
#
#    longitude   latitude
# 0  12.465618  47.785630
# 1  11.577475  48.137597
# 2   8.358280  48.536911
# 3   6.387211  49.535173
# 4   6.926600  49.877600

# %% [markdown]
# -----
# &nbsp;
# ### Count by country

# %%
pivot_table = michelin.pivot_table(index='country', columns=['award'], aggfunc='size', fill_value=0)
pivot_table
# Out:
# award                   1 Star  2 Stars  3 Stars  Bib Gourmand  \
# country
# Andorra                      1        0        0             0
# Argentina                    9        1        0            10
# Austria                     79       19        2            61
# Belgium                    104       18        2           118
# Brazil                      19        5        0            39
# Canada                      36        2        0            58
# Chinese Mainland           117       21        3           252
# Croatia                     12        1        0            12
# Czechia                      8        1        0            18
# Denmark                     27        8        2            20
# Estonia                      1        1        0             7
# Finland                      6        1        0             4
# France                     547       81       30           430
# Germany                    273       45       11           151
# Greece                      11        1        0             6
# Hong Kong SAR China         57       13        7            70
# Hungary                      8        2        0            13
# Iceland                      3        0        0             0
# Ireland                     18        5        0            19
# Italy                      335       38       15           256
# Japan                      274       57       19           234
# Latvia                       2        0        0             5
# Liechtenstein                1        0        0             0
# Lithuania                    3        0        0             8
# Luxembourg                   9        2        0             3
# Macau SAR China             13        6        2            13
# Malaysia                     8        1        0            57
# Malta                        6        1        0             5
# Mexico                      21        2        0            50
# Netherlands                 96       20        1            76
# Norway                      17        1        2             4
# Poland                       6        1        0            21
# Portugal                    44        9        0            26
# Principality of Monaco       5        3        1             0
# Qatar                        3        0        0             8
# Saudi Arabia                 0        0        0            11
# Serbia                       2        0        0             3
# Singapore                   28        7        3            89
# Slovenia                     7        1        1            11
# South Korea                 35       10        1            71
# Spain                      251       37       16           199
# Sweden                      17        4        1            13
# Switzerland                108       27        4           100
# Taiwan                      43        7        3           143
# Thailand                    33        8        2           138
# The Philippines              8        1        0            25
# Türkiye                     15        2        0            38
# USA                        222       40       14           430
# United Arab Emirates        17        3        2            30
# United Kingdom             171       23       10           149
# Vietnam                      9        0        0            62
#
# award                   Selected Restaurants
# country
# Andorra                                    5
# Argentina                                 54
# Austria                                  258
# Belgium                                  501
# Brazil                                    77
# Canada                                   183
# Chinese Mainland                         268
# Croatia                                   73
# Czechia                                   52
# Denmark                                   44
# Estonia                                   30
# Finland                                   20
# France                                  1967
# Germany                                  749
# Greece                                    16
# Hong Kong SAR China                       72
# Hungary                                   54
# Iceland                                    5
# Ireland                                   67
# Italy                                   1321
# Japan                                    530
# Latvia                                    24
# Liechtenstein                              2
# Lithuania                                 25
# Luxembourg                                33
# Macau SAR China                           25
# Malaysia                                  83
# Malta                                     36
# Mexico                                   107
# Netherlands                              301
# Norway                                    24
# Poland                                    78
# Portugal                                 129
# Principality of Monaco                     8
# Qatar                                     33
# Saudi Arabia                              40
# Serbia                                    20
# Singapore                                165
# Slovenia                                  50
# South Korea                              115
# Spain                                    782
# Sweden                                    41
# Switzerland                              294
# Taiwan                                   230
# Thailand                                 294
# The Philippines                           74
# Türkiye                                  112
# USA                                     1053
# United Arab Emirates                     120
# United Kingdom                           756
# Vietnam                                  107

# %%
michelin_filtered = michelin[michelin['award'] != 'Bib Gourmand']
pivot_table_filtered = michelin_filtered.pivot_table(index='country', columns='award', aggfunc='size', fill_value=0)
pivot_table_filtered['total_ratings'] = pivot_table_filtered.sum(axis=1)

# Rank the countries based on the total ratings
pivot_table_filtered['rank'] = pivot_table_filtered['total_ratings'].rank(ascending=False)
pivot_table_sorted = pivot_table_filtered.sort_values(by='rank')
pivot_table_sorted
# Out:
# award                   1 Star  2 Stars  3 Stars  Selected Restaurants  \
# country
# France                     547       81       30                  1967
# Italy                      335       38       15                  1321
# USA                        222       40       14                  1053
# Spain                      251       37       16                   782
# Germany                    273       45       11                   749
# United Kingdom             171       23       10                   756
# Japan                      274       57       19                   530
# Belgium                    104       18        2                   501
# Switzerland                108       27        4                   294
# Netherlands                 96       20        1                   301
# Chinese Mainland           117       21        3                   268
# Austria                     79       19        2                   258
# Thailand                    33        8        2                   294
# Taiwan                      43        7        3                   230
# Canada                      36        2        0                   183
# Singapore                   28        7        3                   165
# Portugal                    44        9        0                   129
# South Korea                 35       10        1                   115
# Hong Kong SAR China         57       13        7                    72
# United Arab Emirates        17        3        2                   120
# Mexico                      21        2        0                   107
# Türkiye                     15        2        0                   112
# Vietnam                      9        0        0                   107
# Brazil                      19        5        0                    77
# Malaysia                     8        1        0                    83
# Ireland                     18        5        0                    67
# Croatia                     12        1        0                    73
# Poland                       6        1        0                    78
# The Philippines              8        1        0                    74
# Denmark                     27        8        2                    44
# Hungary                      8        2        0                    54
# Argentina                    9        1        0                    54
# Sweden                      17        4        1                    41
# Czechia                      8        1        0                    52
# Slovenia                     7        1        1                    50
# Macau SAR China             13        6        2                    25
# Norway                      17        1        2                    24
# Luxembourg                   9        2        0                    33
# Malta                        6        1        0                    36
# Saudi Arabia                 0        0        0                    40
# Qatar                        3        0        0                    33
# Estonia                      1        1        0                    30
# Lithuania                    3        0        0                    25
# Greece                      11        1        0                    16
# Finland                      6        1        0                    20
# Latvia                       2        0        0                    24
# Serbia                       2        0        0                    20
# Principality of Monaco       5        3        1                     8
# Iceland                      3        0        0                     5
# Andorra                      1        0        0                     5
# Liechtenstein                1        0        0                     2
#
# award                   total_ratings  rank
# country
# France                           2625   1.0
# Italy                            1709   2.0
# USA                              1329   3.0
# Spain                            1086   4.0
# Germany                          1078   5.0
# United Kingdom                    960   6.0
# Japan                             880   7.0
# Belgium                           625   8.0
# Switzerland                       433   9.0
# Netherlands                       418  10.0
# Chinese Mainland                  409  11.0
# Austria                           358  12.0
# Thailand                          337  13.0
# Taiwan                            283  14.0
# Canada                            221  15.0
# Singapore                         203  16.0
# Portugal                          182  17.0
# South Korea                       161  18.0
# Hong Kong SAR China               149  19.0
# United Arab Emirates              142  20.0
# Mexico                            130  21.0
# Türkiye                           129  22.0
# Vietnam                           116  23.0
# Brazil                            101  24.0
# Malaysia                           92  25.0
# Ireland                            90  26.0
# Croatia                            86  27.0
# Poland                             85  28.0
# The Philippines                    83  29.0
# Denmark                            81  30.0
# Hungary                            64  31.5
# Argentina                          64  31.5
# Sweden                             63  33.0
# Czechia                            61  34.0
# Slovenia                           59  35.0
# Macau SAR China                    46  36.0
# Norway                             44  37.5
# Luxembourg                         44  37.5
# Malta                              43  39.0
# Saudi Arabia                       40  40.0
# Qatar                              36  41.0
# Estonia                            32  42.0
# Lithuania                          28  43.5
# Greece                             28  43.5
# Finland                            27  45.0
# Latvia                             26  46.0
# Serbia                             22  47.0
# Principality of Monaco             17  48.0
# Iceland                             8  49.0
# Andorra                             6  50.0
# Liechtenstein                       3  51.0

# %%
# Filter out 'Bib Gourmand'
michelin_filtered = michelin[michelin['award'] != 'Bib Gourmand']

# Create a pivot table for the total number of star ratings
star_rating_pivot = michelin_filtered.pivot_table(index='award', aggfunc='size', fill_value=0)
star_rating_pivot.loc['Total'] = star_rating_pivot.sum()
star_rating_pivot
# Out:
# award
# 1 Star                   3145
# 2 Stars                   536
# 3 Stars                   154
# Selected Restaurants    11507
# Total                   15342
# dtype: int64

# %% [markdown]
# ----
#
# ## `awards` columns
#
# In the Michelin dataset, we have a column named 'awards' that designates the level of recognition a restaurant has achieved according to Michelin's rating system. These awards are '3 Stars', '2 Stars', '1 Star', and 'Bib Gourmand', which is a different award for good quality, good value restaurants.
#
# However, in order to make the analysis more tractable and to create a more uniform scale, we transform these awards into numerical values. This transformation will allow us to perform quantitative analysis and make mathematical computations with this data, which wouldn't be possible with the original textual data.
#
# The '3 MICHELIN Stars', '2 MICHELIN Stars', and '1 MICHELIN Star' awards are straightforwardly transformed into the numerical values 3, 2, and 1, respectively. However, the 'Bib Gourmand' award doesn't fit directly into this star system. In consideration of the prestige and value attached to this award, we've decided to map 'Bib Gourmand' to the value 0.5. It's important to note that this decision, while somewhat arbitrary, is made with the understanding that the 'Bib Gourmand' recognizes a different aspect of restaurant quality and is not strictly comparable to the star awards.

# %%
award_dict = {'3 Stars': 3, '2 Stars': 2, '1 Star': 1, 'Bib Gourmand': 0.5, 'Selected Restaurants': 0.25}
michelin['stars'] = michelin['award'].replace(award_dict).infer_objects(copy=False).astype(float)

# %%
cols = michelin.columns.tolist()

cols.remove('stars')
# insert 'stars' at the desired position next to 'award' which we retain
cols.insert(-2, 'stars')

# reindex the DataFrame
michelin = michelin.reindex(columns=cols)

# %%
michelin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18908 entries, 0 to 18907
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       18908 non-null  object
#  1   address    18908 non-null  object
#  2   city       18908 non-null  string
#  3   country    18908 non-null  string
#  4   price      18908 non-null  object
#  5   cuisine    18908 non-null  object
#  6   url        16189 non-null  object
#  7   award      18908 non-null  object
#  8   greenstar  18908 non-null  int64
#  9   stars      18908 non-null  float64
#  10  longitude  18908 non-null  float64
#  11  latitude   18908 non-null  float64
# dtypes: float64(3), int64(1), object(6), string(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ----
# &nbsp;
# ## `price` column
#
# There is also the price column to organise which lists a number of different currencies. It is unclear if, for example, $ refers to USD, HKD etc..
#
# This attribute is easier to deal with piecewise by country

# %% [markdown]
# ----
# &nbsp;
# ## Export `UK` and `France` datasets for further analysis

# %%
# Filter the DataFrame for records where country == 'UK'
uk_data = michelin[michelin['country'] == 'United Kingdom']
uk_data.head()
# Out:
#                                     name  \
# 13287  74 Charlotte Street by Ben Murphy
# 13288                  Pignut & The Hare
# 13289                            Vinette
# 13290                     Restaurant FIR
# 13291                            Cicoria
#
#                                                  address         city  \
# 13287  74 Charlotte Street, Fitzrovia, London, W1T 4Q...       London
# 13288         Hare inn, Scawton, YO7 2HG, United Kingdom      Scawton
# 13289  36 Broughton Street, Edinburgh, EH1 3SB, Unite...    Edinburgh
# 13290  The Vine Tree, Legar Road, Llangattock, NP8 1H...  Llangattock
# 13291  5th Floor, Royal Opera House, Bow Street, Cove...       London
#
#               country price         cuisine  \
# 13287  United Kingdom   £££  Modern British
# 13288  United Kingdom  ££££        Creative
# 13289  United Kingdom    ££  Modern British
# 13290  United Kingdom  ££££  Modern Cuisine
# 13291  United Kingdom   £££         Italian
#
#                                                      url  \
# 13287                     https://74charlottestreet.com/
# 13288                 https://www.pignutandthehare.co.uk
# 13289                          http://www.vinette.co.uk/
# 13290                     https://www.restaurantfir.com/
# 13291  https://www.rbo.org.uk/visit/eat-and-drink/cic...
#
#                       award  greenstar  stars  longitude   latitude
# 13287  Selected Restaurants          0   0.25  -0.136629  51.520543
# 13288  Selected Restaurants          0   0.25  -1.159247  54.243391
# 13289  Selected Restaurants          0   0.25  -3.189809  55.958278
# 13290  Selected Restaurants          0   0.25  -3.142319  51.855309
# 13291  Selected Restaurants          0   0.25  -0.122956  51.513479

# %%
# Export the UK data to a csv file
uk_data.to_csv('../data/UK/uk_data_2026.csv', index=False)

# %%
# Filter the DataFrame for records where country == 'France'
france_data = michelin[michelin['country'] == 'France']
france_data.head()
# Out:
#                          name  \
# 13325  Le Cercle de Montaigne
# 13326                  Épopée
# 13327           La Table 1625
# 13328   L'Épicurieux chez Luc
# 13329             Vertfeuille
#
#                                                  address                city  \
# 13325    144 rue Abbé-de-l'Epée, Bordeaux, 33000, France            Bordeaux
# 13326             52 rue Léon-Frot, Paris, 75011, France               Paris
# 13327   391 route de la Charvaz, Jongieux, 73170, France            Jongieux
# 13328  1080 route des Monts-d'Or, Curis-au-Mont-d'Or,...  Curis-au-Mont-d'Or
# 13329  9 place de l’Eglise, Arc-et-Senans, 25610, France       Arc-et-Senans
#
#       country price              cuisine  \
# 13325  France   €€€       Modern Cuisine
# 13326  France    €€       Modern Cuisine
# 13327  France    €€  Traditional Cuisine
# 13328  France     €  Traditional Cuisine
# 13329  France    €€       Modern Cuisine
#
#                                                      url  \
# 13325  https://www.hotel-palais-gallien-bordeaux.com/...
# 13326                     https://www.epopee-charonne.fr
# 13327  https://www.chateaudelamar.fr/restaurant-la-ta...
# 13328                  https://www.lepicurieuxchezluc.fr
# 13329             https://www.vertfeuille-restaurant.com
#
#                       award  greenstar  stars  longitude   latitude
# 13325  Selected Restaurants          0   0.25  -0.584132  44.846077
# 13326          Bib Gourmand          0   0.50   2.386164  48.856151
# 13327  Selected Restaurants          0   0.25   5.796453  45.742677
# 13328          Bib Gourmand          0   0.50   4.820081  45.870098
# 13329          Bib Gourmand          0   0.50   5.788186  47.036622

# %%
# Define and export Monaco
monaco = michelin[michelin['country'] == 'Principality of Monaco']
monaco.to_csv('../data/France/monaco_2026.csv', index=False)

# %% [markdown]
# We remove Monaco from metropolitan France

# %%
france_data = france_data[france_data['city'] != 'Monaco']
france_data.shape
# Out:
# (3055, 12)

# %%
# Export the France data to a csv file
france_data.to_csv('../data/France/france_master_2026.csv', index=False)

# %% [markdown]
# ----
# &nbsp;
# ## Restaurants could be further partitioned by country from this point
