# %% [markdown]
# # Michelin Rated Restaurants in France - Visualisation

# %%
# Module import
import pandas as pd
import geopandas as gpd

# %%
# Function import
from Functions.functions_visualisation import (dataframe_info, filter_dataframe,
                                               top_restaurants, plot_choropleth, plot_area_info)

# %% [markdown]
# Importing the processed data

# %%
# All restaurants
all_france = pd.read_csv("../../data/France/all_restaurants(arrondissements).csv")

# %% [markdown]
# ----
# &nbsp;
# ### `dataframe_info` function
#
# Provides concise information about a given dataframe
#
# Arguments:
#
# `data` (pandas.DataFrame or gpd.GeoDataFrame):
#
# the function prints out concise details about the dataframe.

# %%
dataframe_info(all_france)
# Out:
# Unique Regions: 13
# Unique Departments: 96
# Unique Arrondissements: 308
# Unique Locations: 1503
#
# Shape: (3055, 16)
#                      name                  address         location  \
# 0  Le Cercle de Montaigne   144 rue Abbé-de-l'Epée  Bordeaux, 33000
# 1                  Épopée         52 rue Léon-Frot     Paris, 75011
# 2           La Table 1625  391 route de la Charvaz  Jongieux, 73170
#
#       arrondissement department_num department   capital  \
# 0           Bordeaux             33    Gironde  Bordeaux
# 1  11th (Popincourt)             75      Paris     Paris
# 2           Chambéry             73     Savoie  Chambéry
#
#                  region price              cuisine  \
# 0    Nouvelle-Aquitaine   €€€       Modern Cuisine
# 1         Île-de-France    €€       Modern Cuisine
# 2  Auvergne-Rhône-Alpes    €€  Traditional Cuisine
#
#                                                  url                 award  \
# 0  https://www.hotel-palais-gallien-bordeaux.com/...  Selected Restaurants
# 1                     https://www.epopee-charonne.fr          Bib Gourmand
# 2  https://www.chateaudelamar.fr/restaurant-la-ta...  Selected Restaurants
#
#    stars  greenstar  longitude   latitude
# 0   0.25          0  -0.584132  44.846077
# 1   0.50          0   2.386164  48.856151
# 2   0.25          0   5.796453  45.742677

# %% [markdown]
# ---
#
# ### `filter_dataframe` function
#
# Filters a dataframe based on specific regions, departments and arrondissements either for inclusion or exclusion.
#
# **Arguments**:
#
# - `data` (pandas.DataFrame): The primary dataframe to filter.
# - `regions` (list[str]/str, optional): Targeted region(s) to include.
# - `departments` (list[str]/str, optional): Targeted department(s) to include.
# - `arrondissements` (list[str]/str, optional): Arrondissement(s) to include.
# - `exclude_regions` (list[str]/str, optional): Region(s) to exclude.
# - `exclude_departments` (list[str]/str, optional): Department(s) to exclude.
# - `exclude_arrondissements` (list[str]/str, optional): Arrondissement(s) to exclude
#
# **Returns**:
#
# - pandas.DataFrame: The dataframe after applying filters.
#
# ##### Usage:
#
# To include or exclude specific regions or departments, provide lists or single strings to the appropriate parameters. For example:
#
# - For specific regions: `regions=['Region1', 'Region2']`
# - To exclude departments: `exclude_departments='DepartmentX'`
#
# The function ensures consistent filtering even with minor discrepancies in naming, thanks to the `_get_best_match` helper function.
#
# ---

# %%
# We define Paris, 75
paris = filter_dataframe(all_france, departments='Paris')
dataframe_info(paris)
# Out:
# Unique Regions: 1
# Unique Departments: 1
# Unique Arrondissements: 20
# Unique Locations: 21
#
# Shape: (455, 16)
#              name               address      location     arrondissement  \
# 1          Épopée      52 rue Léon-Frot  Paris, 75011  11th (Popincourt)
# 25         Felini  50 rue Saint-Georges  Paris, 75009        9th (Opéra)
# 27  Clos d'Astorg       22 rue d'Astorg  Paris, 75008       8th (Élysée)
#
#    department_num department capital         region price  \
# 1              75      Paris   Paris  Île-de-France    €€
# 25             75      Paris   Paris  Île-de-France    €€
# 27             75      Paris   Paris  Île-de-France    €€
#
#                 cuisine                             url                 award  \
# 1        Modern Cuisine  https://www.epopee-charonne.fr          Bib Gourmand
# 25       Modern Cuisine  https://feliniparis.cargo.site  Selected Restaurants
# 27  Traditional Cuisine                             NaN  Selected Restaurants
#
#     stars  greenstar  longitude   latitude
# 1    0.50          0   2.386164  48.856151
# 25   0.25          0   2.337371  48.877406
# 27   0.25          0   2.319682  48.873754

# %% [markdown]
# We can be somewhat imprecise with spelling

# %%
# Exclude Île-de-France
rest_of_france = filter_dataframe(all_france, exclude_regions='ile de france')
dataframe_info(rest_of_france)
# Out:
# Unique Regions: 12
# Unique Departments: 88
# Unique Arrondissements: 265
# Unique Locations: 1430
#
# Shape: (2519, 16)
#                      name                    address  \
# 0  Le Cercle de Montaigne     144 rue Abbé-de-l'Epée
# 2           La Table 1625    391 route de la Charvaz
# 3   L'Épicurieux chez Luc  1080 route des Monts-d'Or
#
#                     location arrondissement department_num department  \
# 0            Bordeaux, 33000       Bordeaux             33    Gironde
# 2            Jongieux, 73170       Chambéry             73     Savoie
# 3  Curis-au-Mont-d'Or, 69250           Lyon             69      Rhône
#
#     capital                region price              cuisine  \
# 0  Bordeaux    Nouvelle-Aquitaine   €€€       Modern Cuisine
# 2  Chambéry  Auvergne-Rhône-Alpes    €€  Traditional Cuisine
# 3      Lyon  Auvergne-Rhône-Alpes     €  Traditional Cuisine
#
#                                                  url                 award  \
# 0  https://www.hotel-palais-gallien-bordeaux.com/...  Selected Restaurants
# 2  https://www.chateaudelamar.fr/restaurant-la-ta...  Selected Restaurants
# 3                  https://www.lepicurieuxchezluc.fr          Bib Gourmand
#
#    stars  greenstar  longitude   latitude
# 0   0.25          0  -0.584132  44.846077
# 2   0.25          0   5.796453  45.742677
# 3   0.50          0   4.820081  45.870098

# %%
# Define 'South of France'
# Capitalisation (or lack of) doesn't matter
south = filter_dataframe(all_france, regions=['Provence', 'aquitaine', 'occitanie', 'auvergne rhone alpes'])
dataframe_info(south)
# Out:
# Unique Regions: 4
# Unique Departments: 43
# Unique Arrondissements: 125
# Unique Locations: 746
#
# Shape: (1417, 16)
#                      name                    address  \
# 0  Le Cercle de Montaigne     144 rue Abbé-de-l'Epée
# 2           La Table 1625    391 route de la Charvaz
# 3   L'Épicurieux chez Luc  1080 route des Monts-d'Or
#
#                     location arrondissement department_num department  \
# 0            Bordeaux, 33000       Bordeaux             33    Gironde
# 2            Jongieux, 73170       Chambéry             73     Savoie
# 3  Curis-au-Mont-d'Or, 69250           Lyon             69      Rhône
#
#     capital                region price              cuisine  \
# 0  Bordeaux    Nouvelle-Aquitaine   €€€       Modern Cuisine
# 2  Chambéry  Auvergne-Rhône-Alpes    €€  Traditional Cuisine
# 3      Lyon  Auvergne-Rhône-Alpes     €  Traditional Cuisine
#
#                                                  url                 award  \
# 0  https://www.hotel-palais-gallien-bordeaux.com/...  Selected Restaurants
# 2  https://www.chateaudelamar.fr/restaurant-la-ta...  Selected Restaurants
# 3                  https://www.lepicurieuxchezluc.fr          Bib Gourmand
#
#    stars  greenstar  longitude   latitude
# 0   0.25          0  -0.584132  44.846077
# 2   0.25          0   5.796453  45.742677
# 3   0.50          0   4.820081  45.870098

# %% [markdown]
# ----
# &nbsp;
# ## Michelin Stars by arrondissement, department and region

# %% [markdown]
# ### `top_restaurants` function
#
# Lists areas with the highest count of Michelin-starred restaurants based on a specified granularity.
#
# **Arguments**:
#
# - `data` (pandas.DataFrame): Contains restaurant details.
# - `granularity` (str): Specifies granularity: 'region', 'department', or 'arrondissement'.
# - `star_rating` (int): Michelin star rating (1, 2, or 3).
# - `top_n` (int): Number of top areas to display.
# - `display_restaurants` (bool, default=True): If True, shows names and locations of restaurants.
# - `display_info` (bool, default=False): If True, provides additional details for each restaurant.
#
# **Behavior**:
#
# 1. **Ranking**: Lists top areas based on count of Michelin-starred restaurants.
# 2. **Restaurant Details**: If `display_restaurants` is True, lists restaurants in each area. Additional details shown if `display_info` is True.

# %% [markdown]
# #### By Region

# %%
top_restaurants(rest_of_france, granularity='region', star_rating=3, top_n=3)
# Out:
# Top 3 regions with most ⭐⭐⭐ restaurants:
#
#
# Region: Auvergne-Rhône-Alpes
# 7 ⭐⭐⭐ Restaurants
# <br>Restaurant: <a href='https://www.troisgros.fr/' target='_blank'>Troisgros - Le Bois sans Feuilles</a><br>Address: 728 route de Villerest<br>Location: Ouches, 42155<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.closdessens.com' target='_blank'>Le Clos des Sens</a><br>Address: 13 rue Jean-Mermoz - à Annecy-le-Vieux<br>Location: Annecy, 74940<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.floconsdesel.com' target='_blank'>Flocons de Sel</a><br>Address: 1775 route du Leutaz, Le Leutaz<br>Location: Megève, 74120<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.anne-sophie-pic.com' target='_blank'>Pic</a><br>Address: 285 avenue Victor-Hugo<br>Location: Valence, 26000<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lesmaisonsmarcon.fr/' target='_blank'>Restaurant Marcon</a><br>Address: Larsiallas, 18 chemin de Brard<br>Location: Saint-Bonnet-le-Froid, 43290<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.chevalblanc.com/fr/maison/courchevel/' target='_blank'>Le 1947 à Cheval Blanc</a><br>Address: Cheval Blanc, Le Jardin Alpin, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.les-morainieres.com' target='_blank'>Les Morainières</a><br>Address: 1400 route de Marestel<br>Location: Jongieux, 73170<br>Style of Cuisine: Creative, Modern Cuisine<br>Price: €€€€<br><br>
# Region: Provence-Alpes-Côte d'Azur
# 7 ⭐⭐⭐ Restaurants
# <br>Restaurant: <a href='https://www.baumaniere.com' target='_blank'>L'Oustau de Baumanière</a><br>Address: 500 route de Baumanière<br>Location: Les Baux-de-Provence, 13520<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.passedat.fr' target='_blank'>Le Petit Nice</a><br>Address: 17 rue des Braves (Anse de Maldormé)<br>Location: Marseille, 13007<br>Style of Cuisine: Seafood<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.chevalblanc.com/fr/maison/st-tropez' target='_blank'>La Vague d'Or - Cheval Blanc St-Tropez</a><br>Address: Plage de la Bouillabaisse<br>Location: Saint-Tropez, 83990<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lavillamadie.com' target='_blank'>La Villa Madie</a><br>Address: Avenue de Revestel<br>Location: Cassis, 13260<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.alexandre-mazzia.com/' target='_blank'>AM par Alexandre Mazzia</a><br>Address: 9 rue François-Rocca<br>Location: Marseille, 13008<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.mirazur.fr/' target='_blank'>Mirazur</a><br>Address: 30 avenue Aristide-Briand<br>Location: Menton, 06500<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.hotelducastellet.net/' target='_blank'>La Table du Castellet</a><br>Address: 3001 route des Hauts-du-Camp, au Circuit Paul Ricard<br>Location: Le Castellet, 83330<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# Region: Nouvelle-Aquitaine
# 2 ⭐⭐⭐ Restaurants
# <br>Restaurant: <a href='https://christophercoutanceau.com' target='_blank'>Christopher Coutanceau</a><br>Address: Plage de la Concurrence<br>Location: La Rochelle, 17000<br>Style of Cuisine: Seafood, Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://lespresdeugenie.com/les-tables/restaurant-etoile-michel-guerard/' target='_blank'>Les Prés d'Eugénie - Michel Guérard</a><br>Address: Place de l'Impératrice<br>Location: Eugénie-les-Bains, 40320<br>Style of Cuisine: Classic Cuisine<br>Price: €€€€<br><br>

# %% [markdown]
# ### By Department

# %%
top_restaurants(south, granularity='department', star_rating=3, top_n=3, display_restaurants=False)
# Out:
# Top 3 departments with most ⭐⭐⭐ restaurants:
#
#
# Department: Bouches-du-Rhône
# 4 ⭐⭐⭐ Restaurants
#
#
# Department: Haute-Savoie
# 2 ⭐⭐⭐ Restaurants
#
#
# Department: Savoie
# 2 ⭐⭐⭐ Restaurants

# %% [markdown]
# ### By *Arrondissement*

# %%
# We choose an out of bounds 'top_n'
paca = filter_dataframe(all_france, regions='Provence')
top_restaurants(paca, granularity='arrondissement', star_rating=3, top_n=5, display_restaurants=False)
# Out:
# Top 5 arrondissements with most ⭐⭐⭐ restaurants:
#
#
# Arrondissement: Marseille
# 3 ⭐⭐⭐ Restaurants
#
#
# Arrondissement: Arles
# 1 ⭐⭐⭐ Restaurant
#
#
# Arrondissement: Draguignan
# 1 ⭐⭐⭐ Restaurant
#
#
# Arrondissement: Nice
# 1 ⭐⭐⭐ Restaurant
#
#
# Arrondissement: Toulon
# 1 ⭐⭐⭐ Restaurant

# %% [markdown]
# ----
# &nbsp;
# ## Loading Geographical Data
#
# The below GeoDataFrames contain Michelin restaurant counts, statistics and geographical data for each regional level

# %%
# Load GeoJSON arrondissement data
arrondissements = gpd.read_file("../../data/France/geodata/arrondissement_restaurants.geojson")
dataframe_info(arrondissements)
# Out:
# GeoDataFrame.
# Unique Regions: 13
# Unique Departments: 96
# Unique Arrondissements: 320
#
# Shape: (320, 20)
#     code   arrondissement department_num department          capital  \
# 0  01001           Belley             01        Ain  Bourg-en-Bresse
# 1  01002  Bourg-en-Bresse             01        Ain  Bourg-en-Bresse
# 2  01003              Gex             01        Ain  Bourg-en-Bresse
#
#                  region  selected  bib_gourmand  1_star  2_star  3_star  \
# 0  Auvergne-Rhône-Alpes         2             0       0       0       0
# 1  Auvergne-Rhône-Alpes        12             5       2       1       0
# 2  Auvergne-Rhône-Alpes         3             0       0       0       0
#
#    total_stars  starred_restaurants  green_stars  municipal_population  \
# 0            0                    0            0              126468.0
# 1            4                    3            1              345948.0
# 2            0                    0            0              104770.0
#
#    population_density(inhabitants/sq_km)  poverty_rate(%)  \
# 0                                   78.8             10.1
# 1                                  119.2              9.1
# 2                                  252.0             12.4
#
#    average_net_hourly_wage(€)  \
# 0                       15.98
# 1                       16.31
# 2                       15.82
#
#                                            locations  \
# 0                        {1: None, 2: None, 3: None}
# 1  {1: [(46.2987913, 4.8826914), (46.4340961, 4.9...
# 2                        {1: None, 2: None, 3: None}
#
#                                             geometry
# 0  POLYGON ((5.12174 45.81118, 5.12665 45.81392, ...
# 1  POLYGON ((4.98022 46.5152, 4.98355 46.51539, 4...
# 2  POLYGON ((6.06401 46.41623, 6.0673 46.41494, 6...

# %%
# Load GeoJSON departmental data
departments = gpd.read_file("../../data/France/geodata/department_restaurants.geojson")
dataframe_info(departments)
# Out:
# GeoDataFrame.
# Unique Regions: 13
# Unique Departments: 96
#
# Shape: (96, 22)
#   code department          capital                region  selected  \
# 0   01        Ain  Bourg-en-Bresse  Auvergne-Rhône-Alpes        17
# 1   02      Aisne             Laon       Hauts-de-France         3
# 2   03     Allier          Moulins  Auvergne-Rhône-Alpes        11
#
#    bib_gourmand  1_star  2_star  3_star  total_stars  ...  GDP_millions(€)  \
# 0             6       3       1       0            5  ...         16726.40
# 1             0       2       0       0            2  ...         12016.40
# 2             0       2       0       0            2  ...          8278.98
#
#    GDP_per_capita(€)  poverty_rate(%)  average_annual_unemployment_rate(%)  \
# 0           24916.84             10.8                                  5.5
# 1           22864.08             18.8                                 10.5
# 2           24734.42             16.2                                  7.8
#
#    average_net_hourly_wage(€)  municipal_population  \
# 0                       15.96              671289.0
# 1                       14.46              525558.0
# 2                       14.19              334715.0
#
#    population_density(inhabitants/sq_km)  area(sq_km)  \
# 0                                  115.1      5832.22
# 1                                   71.7      7329.96
# 2                                   45.6      7340.24
#
#                                            locations  \
# 0  {'Selected': [(46.3626315, 6.0258533), (46.330...
# 1  {'Selected': [(49.6156563, 3.8822523), (49.058...
# 2  {'Selected': [(46.1227974, 3.4219946), (46.712...
#
#                                             geometry
# 0  POLYGON ((4.78021 46.17668, 4.78024 46.18905, ...
# 1  POLYGON ((3.17296 50.01131, 3.17382 50.01186, ...
# 2  POLYGON ((3.03207 46.79491, 3.03424 46.7908, 3...
#
# [3 rows x 22 columns]

# %%
# Load GeoJSON regional data
regions = gpd.read_file("../../data/France/geodata/region_restaurants.geojson")
dataframe_info(regions)
# Out:
# GeoDataFrame.
# Unique Regions: 13
#
# Shape: (13, 19)
#                     region  selected  bib_gourmand  1_star  2_star  3_star  \
# 0            Île-de-France       348            46     112      21       9
# 1      Centre-Val de Loire        73            14      18       1       0
# 2  Bourgogne-Franche-Comté       109            23      29       5       1
#
#    total_stars  starred_restaurants  green_stars  GDP_millions(€)  \
# 0          181                  142           10        700754.40
# 1           20                   19            5         72707.28
# 2           42                   35            4         76921.54
#
#    GDP_per_capita(€)  poverty_rate(%)  average_annual_unemployment_rate(%)  \
# 0       56599.340730        16.148741                             7.023389
# 1       28163.683178        13.465104                             6.831572
# 2       27433.013894        13.402493                             6.416168
#
#    average_net_hourly_wage(€)  municipal_population  \
# 0                   21.275977            12380964.0
# 1                   15.411722             2581597.0
# 2                   14.928133             2803977.0
#
#    population_density(inhabitants/sq_km)  area(sq_km)  \
# 0                                1021.03     12125.93
# 1                                  65.79     39238.50
# 2                                  58.64     47820.55
#
#                                            locations  \
# 0  {'Selected': [(48.877406, 2.337371), (48.87375...
# 1  {'Selected': [(47.3906069, 0.6813315), (48.449...
# 2  {'Selected': [(47.1950195, 4.9660627), (46.968...
#
#                                             geometry
# 0  POLYGON ((2.59052 49.07965, 2.63327 49.10838, ...
# 1  POLYGON ((2.87463 47.52042, 2.88845 47.50943, ...
# 2  POLYGON ((3.62942 46.74946, 3.57569 46.74952, ...

# %% [markdown]
# ---
#
# ### `plot_choropleth` function
#
# Displays a choropleth map from a provided dataset.
#
# **Arguments**:
#
# - `df` (GeoDataFrame): The DataFrame with geospatial data.
# - `column` (str): Column to visualize.
# - `title` (str): Map title.
# - `granularity` (str): Geographical scale - 'region', 'department', or 'arrondissement'. Default is 'department'.
# - `restaurants` (bool): Overlay restaurant locations. Default is False.
# - `show_legend` (bool): Display legend. Default is True.
# - `cmap` (str): Choropleth colormap. Default is 'Blues'.
# - `figsize` (tuple): Map size. Default is (10, 10).
#
# The function checks for column existence and numerical type. It can label regions, departments, or arrondissements based on granularity.
#
# ---

# %% [markdown]
# ##### We choose numerical column `population_density(inhabitants/sq_km)`

# %% [markdown]
# ## All France

# %%
# We make a 'column' error. This returns a list of suitable columns
plot_choropleth(regions, column='population_density', title='Population Density (inhabitants/sq_km)', granularity='region', show_legend=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 # We make a 'column' error. This returns a list of suitable columns
# ----> 2 plot_choropleth(regions, column='population_density', title='Population Density (inhabitants/sq_km)', granularity='region', show_legend=False)
#
# File ~/Documents/Study/Stage3/Programming/Github/Michelin_Rated_Restaurants/Functions/functions_visualisation.py:244, in plot_choropleth(df, column, title, granularity, restaurants, star_rating, show_legend, cmap, figsize)
#     242 # Check if the column exists and contains numerical data
#     243 if column not in df.columns:
# --> 244     raise ValueError(
#     245         f"The column '{column}' does not exist in the DataFrame. "
#     246         f"Available numerical columns are:\n\n{df.select_dtypes(include=['number']).columns.tolist()}")
#     248 if not np.issubdtype(df[column].dtype, np.number):
#     249     raise ValueError(
#     250         f"The column '{column}' does not contain numerical data. "
#     251         f"Available numerical columns are:\n\n{df.select_dtypes(include=['number']).columns.tolist()}")
#
# ValueError: The column 'population_density' does not exist in the DataFrame. Available numerical columns are:
#
# ['selected', 'bib_gourmand', '1_star', '2_star', '3_star', 'total_stars', 'starred_restaurants', 'green_stars', 'GDP_millions(€)', 'GDP_per_capita(€)', 'poverty_rate(%)', 'average_annual_unemployment_rate(%)', 'average_net_hourly_wage(€)', 'municipal_population', 'population_density(inhabitants/sq_km)', 'area(sq_km)']

# %%
# We exclude Île-de-France
no_ile_de_france = filter_dataframe(regions, exclude_regions='ile de france')

plot_choropleth(no_ile_de_france, column='population_density(inhabitants/sq_km)',
                title='Population Density (inhabitants/sq_km)', granularity='region',
                show_legend=False)

# %% [markdown]
# ----
# &nbsp;
# ## Regions

# %% [markdown]
# ### Auvergne-Rhône-Alpes

# %% [markdown]
# By Department

# %%
rhone_dept = filter_dataframe(departments, regions='auvergne rhone alpes')
plot_choropleth(rhone_dept, column='population_density(inhabitants/sq_km)', title='Population Density (inhabitants/sq_km)', granularity='department', restaurants=True, show_legend=True)

# %% [markdown]
# By *Arrondissement*
#
# Removing Lyon Metropole

# %%
# Isolate Auvergne-Rhône-Alpes
rhone_arron = filter_dataframe(arrondissements, regions='auvergne rhone alpes')

# Remove Lyon
rhone_no_lyon = filter_dataframe(rhone_arron, exclude_arrondissements='lyon')

plot_choropleth(rhone_no_lyon, column='population_density(inhabitants/sq_km)', title='Population Density (inhabitants/sq_km)', granularity='arrondissement', restaurants=False, show_legend=True)

# %% [markdown]
# ##### If the region is large (as above), creating smaller groups of departments will produce a less cluttered graph

# %% [markdown]
# #### Zoom in Savoie

# %%
savoie = filter_dataframe(departments, departments=['savoie', 'haut savoie'])
plot_choropleth(savoie, column='population_density(inhabitants/sq_km)',
                title='Population Density (inhabitants/sq_km)', granularity='department',
                restaurants=True, show_legend=True)

# %%
savoie = filter_dataframe(arrondissements, departments=['savoie', 'haut savoie'])
plot_choropleth(savoie, column='population_density(inhabitants/sq_km)',
                title='Population Density (inhabitants/sq_km)', granularity='arrondissement',
                restaurants=True, show_legend=True)

# %% [markdown]
# ----
# &nbsp;
# ## Nouvelle-Aquitaine

# %%
aquitaine = filter_dataframe(departments, regions='aquitaine')
dataframe_info(aquitaine)
# Out:
# GeoDataFrame.
# Unique Regions: 1
# Unique Departments: 12
#
# Shape: (12, 22)
#    code         department      capital              region  selected  \
# 17   16           Charente    Angoulême  Nouvelle-Aquitaine         3
# 18   17  Charente-Maritime  La Rochelle  Nouvelle-Aquitaine        28
# 20   19            Corrèze        Tulle  Nouvelle-Aquitaine         9
#
#     bib_gourmand  1_star  2_star  3_star  total_stars  ...  GDP_millions(€)  \
# 17             2       6       0       0            6  ...         10580.40
# 18             9       1       0       1            4  ...         16887.80
# 20             5       2       0       0            2  ...          6115.33
#
#     GDP_per_capita(€)  poverty_rate(%)  average_annual_unemployment_rate(%)  \
# 17           30091.89             15.1                                  6.9
# 18           25275.08             12.5                                  6.8
# 20           25467.81             13.7                                  6.0
#
#     average_net_hourly_wage(€)  municipal_population  \
# 17                       14.77              351603.0
# 18                       14.81              668160.0
# 20                       14.27              240120.0
#
#     population_density(inhabitants/sq_km)  area(sq_km)  \
# 17                                   58.9      5969.49
# 18                                   96.4      6931.12
# 20                                   40.9      5870.90
#
#                                             locations  \
# 17  {'Selected': [(45.824475, 0.4511441), (45.6997...
# 18  {'Selected': [(46.161251, -1.149134), (45.9780...
# 20  {'Selected': [(45.43152, 1.45058), (45.1668776...
#
#                                              geometry
# 17  POLYGON ((-0.10294 45.96966, -0.09758 45.97113...
# 18  MULTIPOLYGON (((-1.11427 45.95173, -1.1163 45....
# 20  POLYGON ((1.89873 45.69828, 1.89931 45.69828, ...
#
# [3 rows x 22 columns]

# %%
plot_choropleth(aquitaine, column='population_density(inhabitants/sq_km)',
                title='Population Density (inhabitants/sq_km)', granularity='department',
                restaurants=True, show_legend=True)

# %% [markdown]
# #### Zoom in Atlantic Coast

# %%
# Whole departments
atlantic = filter_dataframe(departments, departments=['gironde', 'landes', 'pyrennes atlantique'])
plot_choropleth(atlantic, column='population_density(inhabitants/sq_km)',
                title='Population Density (inhabitants/sq_km)', granularity='department',
                restaurants=True, show_legend=True)

# %% [markdown]
# #### Zoom in Gironde
# (Arrondissement level)

# %%
gironde = filter_dataframe(arrondissements, departments=['gironde'])
plot_choropleth(gironde, column='population_density(inhabitants/sq_km)',
                title='Population Density (inhabitants/sq_km)', granularity='arrondissement',
                restaurants=True, show_legend=True)

# %% [markdown]
# ---
#
# ### `plot_area_info` function
#
# Plots Michelin Starred Restaurants on a map for a specified department or arrondissement and optionally displays related demographic and restaurant-specific info.
#
# **Arguments**:
#
# - `geo_df` (GeoDataFrame): Geospatial dataframe containing boundaries and statistics.
# - `data_df` (DataFrame): Dataframe containing restaurant information
# - `code_or_name` (str or int): The name of the department/arrondissement or the code.
# - `display_restaurants` (bool, optional): If True, plots the location of Michelin Starred Restaurants on the map. Default is True.
# - `display_info` (bool, optional): If True, prints additional info for each restaurant. Default is False.
# - `figsize` (tuple, optional): Size of the plotted map. Default is (10, 10).
#
# **Returns**:
#
# - None: Displays a map and prints relevant demographic and restaurant-specific info.
#
# 1. **Visualization**: The function plots the department with its restaurants, color-coding based on Michelin star rating (1 to 3 stars).
# 2. **Demographics**: Displays statistics like population, GDP per capita, unemployment rate, and more for the chosen department.
# 3. **Starred Restaurants**: Lists out Michelin starred restaurants in the department. If `display_info` is set to True, detailed information for each restaurant is printed, including the address, cuisine style, and website.
#
# ##### Usage:
#
# ```python
# plot_area_info(geo_df=arrondissements, data_df=all_france, code_or_name='Nice', display_restaurants=True, display_info=True)
# ```

# %%
plot_area_info(departments, all_france, '73', display_info=True)
# Out:
# Demographics of Savoie:
#
# Region: Auvergne-Rhône-Alpes
# Capital: Chambéry
# Municipal Population: 445288.0
# Population Density(inhabitants/sq Km): 73.4
# Area(sq Km): 6066.59
# Average Net Hourly Wage(€): 16.32
# Poverty Rate(%): 11.2
# Average Annual Unemployment Rate(%): 5.2
# GDP Per Capita(€): 34136.56
#
#
#
#
# 2 ⭐⭐⭐ Restaurants:
# <br>Restaurant: <a href='https://www.chevalblanc.com/fr/maison/courchevel/' target='_blank'>Le 1947 à Cheval Blanc</a><br>Address: Cheval Blanc, Le Jardin Alpin, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.les-morainieres.com' target='_blank'>Les Morainières</a><br>Address: 1400 route de Marestel<br>Location: Jongieux, 73170<br>Style of Cuisine: Creative, Modern Cuisine<br>Price: €€€€<br><br>
# 4 ⭐⭐ Restaurants:
# <br>Restaurant: <a href='https://www.la-bouitte.com' target='_blank'>René et Maxime Meilleur</a><br>Address: Hameau de Saint-Marcel<br>Location: Saint-Martin-de-Belleville, 73440<br>Style of Cuisine: Creative, Regional Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.hotelstrato.com/' target='_blank'>Baumanière 1850</a><br>Address: Le Strato, Route de Bellecôte, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lek2palace.com/fr/deguster/le-sarkara.html' target='_blank'>Le Sarkara</a><br>Address: Le K2 Palace, 238 rue des Clarines, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://restaurantsylvestre.com' target='_blank'>Sylvestre Wahid - Les Grandes Alpes</a><br>Address: 28 rue de l'Église, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# 13 ⭐ Restaurants:
# <br>Restaurant: <a href='https://www.hotellesbarmes.com' target='_blank'>La Table de l'Ours</a><br>Address: Les Barmes de l'Ours, 100 montée de Bellevarde<br>Location: Val-d'Isère, 73150<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.hotelpashmina.com/' target='_blank'>Les Explorateurs - Hôtel Pashmina</a><br>Address: 141 rue des Dalles<br>Location: Val-Thorens, 73440<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.chabichou-courchevel.com' target='_blank'>Le Chabichou by Stéphane Buron</a><br>Address: 90 rue des Chenus, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.annapurna-courchevel.com/fr/restaurant-alpage.html' target='_blank'>Alpage</a><br>Address: Annapurna, 734 route de l'Altiport, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lek2altitude.com/fr/deguster/l-altitude.html' target='_blank'>L'Altitude</a><br>Address: Le K2 Altitude, 356 route de l'Altiport, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Classic Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.montblanc-restaurant.com' target='_blank'>Mont Blanc Restaurant & Goûter</a><br>Address: 16 rue de la Voûte<br>Location: Hauteluce, 73620<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.les-suites-du-nevada.com/restaurant-ursus/' target='_blank'>Ursus</a><br>Address: Maison Bouvier - Les Suites, 39 rue du Val-Claret, au Val-Claret<br>Location: Tignes, 73320<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://hotel-lincomparable.com/' target='_blank'>La Table de L'Incomparable</a><br>Address: 68 chemin de Belledonne<br>Location: Tresserve, 73100<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lekaila.com' target='_blank'>L'Ekrin by Laurent Azoulay</a><br>Address: Le Kaïla, 124 rue des Jeux-Olympiques<br>Location: Méribel, 73550<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.chambres-d-hote-maurienne-le-clocher-des-peres.fr' target='_blank'>Le Clocher des Pères</a><br>Address: Le Mollard, 80 impasse du Four<br>Location: Saint-Martin-sur-la-Chambre, 73130<br>Style of Cuisine: Modern Cuisine, Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lefarcon.fr/' target='_blank'>Le Farçon</a><br>Address: Immeuble Kalinka, La Tania<br>Location: Courchevel, 73120<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.atmospheres-hotel.com' target='_blank'>Atmosphères</a><br>Address: 618 route des Tournelles<br>Location: Le Bourget-du-Lac, 73370<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lamartine-marin.com' target='_blank'>Lamartine</a><br>Address: 3132 route du Tunnel, Bourdeau<br>Location: Le Bourget-du-Lac, 73370<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>

# %%
plot_area_info(arrondissements, all_france, 'albertville', display_info=False)
# Out:
# Demographics of Albertville:
#
# Region: Auvergne-Rhône-Alpes
# Capital: Chambéry
# Municipal Population: 112282.0
# Population Density(inhabitants/sq Km): 45.5
# Average Net Hourly Wage(€): 15.8
# Poverty Rate(%): 12.8
#
#
#
#
# 1 ⭐⭐⭐ Restaurant:
#
#
# 4 ⭐⭐ Restaurants:
#
#
# 9 ⭐ Restaurants:

# %%
plot_area_info(departments, all_france, '33', display_info=True)
# Out:
# Demographics of Gironde:
#
# Region: Nouvelle-Aquitaine
# Capital: Bordeaux
# Municipal Population: 1674980.0
# Population Density(inhabitants/sq Km): 165.9
# Area(sq Km): 10096.32
# Average Net Hourly Wage(€): 16.7
# Poverty Rate(%): 12.8
# Average Annual Unemployment Rate(%): 6.5
# GDP Per Capita(€): 33365.83
#
#
#
#
# 7 ⭐⭐ Restaurants:
# <br>Restaurant: <a href='https://haaitza.com/' target='_blank'>Le Skiff Club</a><br>Address: Hôtel Ha(a)ïtza, 1 avenue Louis-Gaume<br>Location: Pyla-sur-Mer, 33115<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://bordeaux.intercontinental.com/le-pressoir-dargent-gordon-ramsay/' target='_blank'>Le Pressoir d'Argent - Gordon Ramsay</a><br>Address: InterContinental Bordeaux - Le Grand Hôtel, 2-5 place de la Comédie<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lafauriepeyragueylalique.com/le-restaurant/' target='_blank'>Lalique</a><br>Address: 1707 route des Gourgues<br>Location: Bommes, 33210<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.hoteldepavie.com' target='_blank'>La Table de Pavie</a><br>Address: Hôtel de Pavie, 5 place du Clocher<br>Location: Saint-Emilion, 33330<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.sources-hotels.com/bordeaux/restaurants/restaurant-grand-vigne/' target='_blank'>La Grand'Vigne - Les Sources de Caudalie</a><br>Address: Chemin de Smith-Haut-Lafitte<br>Location: Martillac, 33650<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://le-gabriel-bordeaux.fr' target='_blank'>L'Observatoire du Gabriel</a><br>Address: 10 place de la Bourse<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine, Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.maison-nouvelle.fr' target='_blank'>Maison Nouvelle</a><br>Address: 11 rue Rode<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# 16 ⭐ Restaurants:
# <br>Restaurant: <a href='https://www.leprincenoir-restaurant.com' target='_blank'>Le Prince Noir - Vivien Durand</a><br>Address: 1 rue du Prince-Noir<br>Location: Lormont, 33310<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://solena-restaurant.com/' target='_blank'>Soléna</a><br>Address: 5 rue Chauffour<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.saintjames-bouliac.com' target='_blank'>Le Saint-James</a><br>Address: 3 place Camille-Hosteins<br>Location: Bouliac, 33270<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lecercleguiraud.com/' target='_blank'>Le Cercle Guiraud</a><br>Address: 14 rue Principale<br>Location: Sauternes, 33210<br>Style of Cuisine: Modern Cuisine<br>Price: €€€<br><br>
# <br>Restaurant: <a href='https://www.restaurant-amicis.fr/' target='_blank'>Amicis</a><br>Address: 19 rue Mably<br>Location: Bordeaux, 33000<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://cent33.com/' target='_blank'>Cent33</a><br>Address: 133 rue du Jardin-Public<br>Location: Bordeaux, 33000<br>Style of Cuisine: Creative<br>Price: €€€<br><br>
# <br>Restaurant: <a href='https://www.aubergesaintjean.com/' target='_blank'>L'Auberge Saint Jean</a><br>Address: 90 rue du Pont<br>Location: Saint-Jean-de-Blaignac, 33420<br>Style of Cuisine: Modern Cuisine<br>Price: €€€<br><br>
# <br>Restaurant: <a href='https://www.logisdelacadene.fr' target='_blank'>Logis de la Cadène</a><br>Address: 3 place du Marché-au-Bois<br>Location: Saint-Emilion, 33330<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lepavillondesboulevards.fr' target='_blank'>Le Pavillon des Boulevards</a><br>Address: 120 rue de la Croix-de-Seguey<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.loiseaubleu.fr/' target='_blank'>L'Oiseau Bleu</a><br>Address: 127 avenue Thiers<br>Location: Bordeaux, 33100<br>Style of Cuisine: Modern Cuisine<br>Price: €€€<br><br>
# <br>Restaurant: <a href='https://quatrieme-mur.com/' target='_blank'>La Table d'Hôtes - Le Quatrième Mur</a><br>Address: 2 place de la Comédie<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine, Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.lepatio-thierryrenou.com/' target='_blank'>Le Patio</a><br>Address: 10 boulevard de la Plage<br>Location: Arcachon, 33120<br>Style of Cuisine: Modern Cuisine<br>Price: €€€<br><br>
# <br>Restaurant: <a href='https://tentazioni-bordeaux.com/' target='_blank'>Tentazioni</a><br>Address: 59 rue du Palais-Gallien<br>Location: Bordeaux, 33000<br>Style of Cuisine: Italian, Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://troplong-mondot.com/restaurant' target='_blank'>Les Belles Perdrix de Troplong Mondot</a><br>Address: Château Troplong Mondot<br>Location: Saint-Emilion, 33330<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.restaurant-nacre.com/' target='_blank'>Nacre</a><br>Address: 3 bis rue Sophie-et-Paul-Wallerstein<br>Location: Arès, 33740<br>Style of Cuisine: Modern Cuisine<br>Price: €€€<br><br>
# <br>Restaurant: <a href='https://restaurantressources.com/' target='_blank'>Ressources</a><br>Address: 126 rue Fondaudège<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine<br>Price: €€€<br><br>

# %%
plot_area_info(arrondissements, all_france, 'bordeaux', display_info=False)
# Out:
# Demographics of Bordeaux:
#
# Region: Nouvelle-Aquitaine
# Capital: Bordeaux
# Municipal Population: 1027237.0
# Population Density(inhabitants/sq Km): 665.7
# Average Net Hourly Wage(€): 17.42
# Poverty Rate(%): 12.9
#
#
#
#
# 4 ⭐⭐ Restaurants:
#
#
# 10 ⭐ Restaurants:

# %% [markdown]
# The function also handles departments with zero starred restaurants

# %%
plot_area_info(departments, all_france, '82', display_info=True)
# Out:
# Demographics of Tarn-et-Garonne:
#
# Region: Occitanie
# Capital: Montauban
# Municipal Population: 264924.0
# Population Density(inhabitants/sq Km): 70.8
# Area(sq Km): 3741.86
# Average Net Hourly Wage(€): 14.58
# Poverty Rate(%): 16.7
# Average Annual Unemployment Rate(%): 8.6
# GDP Per Capita(€): 22800.69

# %% [markdown]
# ----
# &nbsp;
# # [Michelin App](https://www.restaurant-guide-france.net)
#
# Built using Dash, the app integrates data visualization with Plotly to display Michelin-rated restaurants across French departments sourced from CSV and GeoJSON files.
#
# It provides an interactive map that adjusts based on user input from dropdowns, showing different restaurant ratings color-coded by star count, and utilizes hover features to present detailed information about each establishment.
#
# it employs Dash Bootstrap Components and integrates dynamic callbacks to update visualizations in real-time.
