# %% [markdown]
# # Comparing the 2024 and 2025 Michelin Guide to France

# %%
import pandas as pd

# %%
france_25 = pd.read_csv('../../../2025/data/France/all_restaurants(arrondissements).csv')
france_26 = pd.read_csv('../../data/France/all_restaurants(arrondissements).csv')

# %%
france_25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2985 entries, 0 to 2984
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2985 non-null   object
#  1   address         2985 non-null   object
#  2   location        2985 non-null   object
#  3   arrondissement  2978 non-null   object
#  4   department_num  2985 non-null   object
#  5   department      2985 non-null   object
#  6   capital         2985 non-null   object
#  7   region          2985 non-null   object
#  8   price           2985 non-null   object
#  9   cuisine         2985 non-null   object
#  10  url             2831 non-null   object
#  11  award           2985 non-null   object
#  12  stars           2985 non-null   float64
#  13  greenstar       2985 non-null   int64
#  14  longitude       2985 non-null   float64
#  15  latitude        2985 non-null   float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 373.3+ KB

# %%
france_26.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3055 entries, 0 to 3054
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            3055 non-null   object
#  1   address         3055 non-null   object
#  2   location        3055 non-null   object
#  3   arrondissement  3048 non-null   object
#  4   department_num  3055 non-null   object
#  5   department      3055 non-null   object
#  6   capital         3055 non-null   object
#  7   region          3055 non-null   object
#  8   price           3055 non-null   object
#  9   cuisine         3055 non-null   object
#  10  url             2894 non-null   object
#  11  award           3055 non-null   object
#  12  stars           3055 non-null   float64
#  13  greenstar       3055 non-null   int64
#  14  longitude       3055 non-null   float64
#  15  latitude        3055 non-null   float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 382.0+ KB

# %%
non_selected_26 = france_26[france_26['stars'] != 0.25]
print(len(non_selected_26))
# Out:
# 1088

# %% [markdown]
# ----
# &nbsp;
# ## Identify new or removed entries focusing on 1+ star restaurants

# %%
# Filter france_25 and france_26 for star ratings >= 1
subset_25 = france_25[france_25['stars'] >= 1][['name', 'address', 'location', 'url', 'stars']]
subset_26 = france_26[france_26['stars'] >= 1][['name', 'address', 'location', 'url', 'stars']]

# Turn the filtered data into sets of tuples
set_subset_25 = set(tuple(x) for x in subset_25.values)
set_subset_26 = set(tuple(x) for x in subset_26.values)

# Find new and closed Michelin stars
potential_new_stars = set_subset_26 - set_subset_25
potential_closed_stars = set_subset_25 - set_subset_26

# %%
print(f'Potentially entered the guide:\n{len(potential_new_stars)} starred restaurants in 2026 guide not in 2025')
print(f'\nPotentially left the guide:\n{len(potential_closed_stars)} starred restaurants in 2025 guide not in 2026')
# Out:
# Potentially entered the guide:
# 415 starred restaurants in 2026 guide not in 2025
#
# Potentially left the guide:
# 403 starred restaurants in 2025 guide not in 2026

# %% [markdown]
# ----
# &nbsp;
# ### Using Pandas method
# #### The above does not tell us how the distribution has changed.

# %%
# Now find name changes. For this, we need to find common addresses with different names
common_locations = set(subset_25['url']).intersection(set(subset_26['url']))

# Filtering out the common url from both DataFrames
common_25 = subset_25[subset_25['url'].isin(common_locations)]
common_26 = subset_26[subset_26['url'].isin(common_locations)]

# %%
# Merge the data frames on 'url' and 'location'
merged_df = pd.merge(common_25, common_26, on=['url', 'location'], suffixes=('_25', '_26'))

# Filter entries where names or star ratings have changed
name_star_changes = merged_df[(merged_df['name_25'] != merged_df['name_26']) | (merged_df['stars_25'] != merged_df['stars_26'])]

# Rename columns to reflect the data properly
name_star_changes = name_star_changes[['name_25', 'name_26', 'address_25', 'address_26', 'location', 'stars_25', 'stars_26']]

# %%
name_star_changes
# Out:
#                                    name_25  \
# 0                              L'Ambroisie
# 17                      Relais de la Poste
# 45                           Bulle d'Osier
# 55                                Alliance
# 57                                  Hakuba
# 135                                 Virtus
# 168  La Table - Christophe Hay et Loïs Bée
# 169                   Domaine du Colombier
# 198       Thierry Schwartz - Le Restaurant
# 215          La Table des Frères Ibarboure
# 238                               Le Corot
# 241                        Le Pourquoi Pas
# 253                            Sechex-Nous
#
#                                     name_26  \
# 0                               L'Ambroisie
# 17                       Relais de la Poste
# 45                            Bulle d'Osier
# 55                                 Alliance
# 57                                   Hakuba
# 135                                  Virtus
# 168  La Table de Christophe Hay et Loïs Bée
# 169                            Le Colombier
# 198      Thierry Schwartz - Table Naturelle
# 215                    Les Frères Ibarboure
# 238                                Le Corot
# 241                            Pourquoi Pas
# 253                             Séchex Nous
#
#                                         address_25  \
# 0                               9 place des Vosges
# 17                            24 avenue de Maremne
# 45      Clos Vauban, 1 place du Colonel-de-Grouchy
# 55                                 5 rue de Poissy
# 57            Cheval Blanc Paris, 8 quai du Louvre
# 135                                29 rue de Cotte
# 168  200 allée des Quatre-Vents, au golf de Limère
# 169                         270 chemin de Malombre
# 198                             35 rue de Sélestat
# 215                           281 chemin Ttalienea
# 238                           55 rue de Versailles
# 241           Hôtel Castelbrac, 17 avenue George-V
# 253              Port de Séchex 2 route des Meules
#
#                                         address_26              location  \
# 0                               9 place des Vosges          Paris, 75004
# 17                            24 avenue de Maremne        Magescq, 40140
# 45      Clos Vauban, 1 place du Colonel-de-Grouchy        Langres, 52200
# 55                                 5 rue de Poissy          Paris, 75005
# 57            Cheval Blanc Paris, 8 quai du Louvre          Paris, 75001
# 135                                29 rue de Cotte          Paris, 75012
# 168  200 allée des Quatre-Vents, au golf de Limère          Ardon, 45160
# 169                         270 chemin de Malombre    Malataverne, 26780
# 198                             35 rue de Sélestat        Obernai, 67210
# 215                           281 chemin Ttalienea         Bidart, 64210
# 238      Les Étangs de Corot, 55 rue de Versailles  Ville-d'Avray, 92410
# 241           Hôtel Castelbrac, 17 avenue George-V         Dinard, 35800
# 253            2 route des Meules (Port de Séchex)      Margencel, 74200
#
#      stars_25  stars_26
# 0         3.0       2.0
# 17        2.0       1.0
# 45        1.0       2.0
# 55        1.0       2.0
# 57        1.0       2.0
# 135       1.0       2.0
# 168       1.0       1.0
# 169       1.0       1.0
# 198       1.0       1.0
# 215       1.0       1.0
# 238       1.0       2.0
# 241       1.0       1.0
# 253       1.0       1.0

# %% [markdown]
# We're focusing on the changes from ⭐️$\implies$⭐️⭐️ and from ⭐️⭐️$\implies$⭐️⭐️⭐️ (or significant demotions)

# %% [markdown]
# We assign a similarity score to the different names and change `france_23` in place

# %%
from fuzzywuzzy import fuzz

# Function to preprocess and compare names
def preprocess(text):
    # Basic preprocessing: lowercasing and stripping spaces
    return text.lower().strip()

def compare_names(name1, name2):
    name1 = preprocess(name1)
    name2 = preprocess(name2)
    return fuzz.token_sort_ratio(name1, name2)  # Comparing with sorted tokens to handle reordering

# Applying the comparison across the DataFrame rows
name_star_changes['similarity_score'] = name_star_changes.apply(lambda x: compare_names(x['name_25'], x['name_26']), axis=1)

# %%
name_star_changes
# Out:
#                                    name_25  \
# 0                              L'Ambroisie
# 17                      Relais de la Poste
# 45                           Bulle d'Osier
# 55                                Alliance
# 57                                  Hakuba
# 135                                 Virtus
# 168  La Table - Christophe Hay et Loïs Bée
# 169                   Domaine du Colombier
# 198       Thierry Schwartz - Le Restaurant
# 215          La Table des Frères Ibarboure
# 238                               Le Corot
# 241                        Le Pourquoi Pas
# 253                            Sechex-Nous
#
#                                     name_26  \
# 0                               L'Ambroisie
# 17                       Relais de la Poste
# 45                            Bulle d'Osier
# 55                                 Alliance
# 57                                   Hakuba
# 135                                  Virtus
# 168  La Table de Christophe Hay et Loïs Bée
# 169                            Le Colombier
# 198      Thierry Schwartz - Table Naturelle
# 215                    Les Frères Ibarboure
# 238                                Le Corot
# 241                            Pourquoi Pas
# 253                             Séchex Nous
#
#                                         address_25  \
# 0                               9 place des Vosges
# 17                            24 avenue de Maremne
# 45      Clos Vauban, 1 place du Colonel-de-Grouchy
# 55                                 5 rue de Poissy
# 57            Cheval Blanc Paris, 8 quai du Louvre
# 135                                29 rue de Cotte
# 168  200 allée des Quatre-Vents, au golf de Limère
# 169                         270 chemin de Malombre
# 198                             35 rue de Sélestat
# 215                           281 chemin Ttalienea
# 238                           55 rue de Versailles
# 241           Hôtel Castelbrac, 17 avenue George-V
# 253              Port de Séchex 2 route des Meules
#
#                                         address_26              location  \
# 0                               9 place des Vosges          Paris, 75004
# 17                            24 avenue de Maremne        Magescq, 40140
# 45      Clos Vauban, 1 place du Colonel-de-Grouchy        Langres, 52200
# 55                                 5 rue de Poissy          Paris, 75005
# 57            Cheval Blanc Paris, 8 quai du Louvre          Paris, 75001
# 135                                29 rue de Cotte          Paris, 75012
# 168  200 allée des Quatre-Vents, au golf de Limère          Ardon, 45160
# 169                         270 chemin de Malombre    Malataverne, 26780
# 198                             35 rue de Sélestat        Obernai, 67210
# 215                           281 chemin Ttalienea         Bidart, 64210
# 238      Les Étangs de Corot, 55 rue de Versailles  Ville-d'Avray, 92410
# 241           Hôtel Castelbrac, 17 avenue George-V         Dinard, 35800
# 253            2 route des Meules (Port de Séchex)      Margencel, 74200
#
#      stars_25  stars_26  similarity_score
# 0         3.0       2.0               100
# 17        2.0       1.0               100
# 45        1.0       2.0               100
# 55        1.0       2.0               100
# 57        1.0       2.0               100
# 135       1.0       2.0               100
# 168       1.0       1.0                96
# 169       1.0       1.0                69
# 198       1.0       1.0                65
# 215       1.0       1.0                77
# 238       1.0       2.0               100
# 241       1.0       1.0                89
# 253       1.0       1.0                95

# %%
# Filter rows where the similarity score is greater than 65 (by inspection)
high_similarity_rows = name_star_changes[name_star_changes['similarity_score'] >= 65]

# %%
# Iterate over these rows to update the names in france_25
for _, row in high_similarity_rows.iterrows():
    # Update france_25 where the url and location match
    france_25.loc[(france_25['address'] == row['address_25']) & (france_26['location'] == row['location']), 'name'] = row['name_26']

# %% [markdown]
# ---
# &nbsp;
# ### New ⭐⭐⭐ Restaurants, New ⭐⭐ Restaurants and demotions

# %%
# Identify New Two-Star and Three-Star Restaurants
# Filter france_24 and france_25 for star ratings >= 1
subset_25 = france_25[france_25['stars'] >= 1][['name', 'address', 'location', 'url', 'stars']]
subset_26 = france_26[france_26['stars'] >= 1][['name', 'address', 'location', 'url', 'stars']]

# %%
# Now find name changes. For this, we need to find common addresses with different names
common_locations = set(subset_25['name']).intersection(set(subset_26['name']))

# Filtering out the common url from both DataFrames
common_25 = subset_25[subset_25['name'].isin(common_locations)]
common_26 = subset_26[subset_26['name'].isin(common_locations)]

# %%
# Merge the data frames on 'name' and 'location'
merged_df = pd.merge(common_25, common_26, on=['name', 'location', 'url'], suffixes=('_25', '_26'))

# %%
# Filter entries where names or star ratings have changed
star_changes = merged_df[(merged_df['stars_25'] != merged_df['stars_26'])]

# Rename columns to reflect the data properly
star_changes = star_changes[['name', 'address_26', 'location', 'url', 'stars_25', 'stars_26']]

# %%
star_changes
# Out:
#                    name                                  address_26  \
# 0           L'Ambroisie                          9 place des Vosges
# 17   Relais de la Poste                        24 avenue de Maremne
# 45        Bulle d'Osier  Clos Vauban, 1 place du Colonel-de-Grouchy
# 55             Alliance                             5 rue de Poissy
# 57               Hakuba        Cheval Blanc Paris, 8 quai du Louvre
# 135              Virtus                             29 rue de Cotte
# 234            Le Corot   Les Étangs de Corot, 55 rue de Versailles
#
#                  location                                                url  \
# 0            Paris, 75004                   https://www.ambroisie-paris.com/
# 17         Magescq, 40140                        https://www.relaisposte.com
# 45         Langres, 52200                            https://closvauban.com/
# 55           Paris, 75005                https://www.restaurant-alliance.fr/
# 57           Paris, 75001  https://www.chevalblanc.com/fr/maison/paris/re...
# 135          Paris, 75012                       https://www.virtus-paris.com
# 234  Ville-d'Avray, 92410                      https://www.etangs-corot.com/
#
#      stars_25  stars_26
# 0         3.0       2.0
# 17        2.0       1.0
# 45        1.0       2.0
# 55        1.0       2.0
# 57        1.0       2.0
# 135       1.0       2.0
# 234       1.0       2.0

# %% [markdown]
# We now need to find new entries at two star and three star

# %%
# Convert subset DataFrames to sets of tuples to identify unique restaurants
unique_25 = set(tuple(x) for x in subset_25[['name', 'location', 'stars']].values)
unique_26 = set(tuple(x) for x in subset_26[['name', 'location', 'stars']].values)

# Identify new restaurants in 2024 that were not in 2023
new_restaurants = unique_26 - unique_25

# Convert the set of new restaurants back to a DataFrame
df = pd.DataFrame(list(new_restaurants), columns=['name', 'location', 'stars'])

# Filter for restaurants that have two or three stars
new_high_stars = df[(df['stars'] == 2) | (df['stars'] == 3)]

new_high_stars = new_high_stars.sort_values(by=['stars'], ascending=[False])

# %%
new_high_stars
# Out:
#                               name              location  stars
# 68                 Les Morainières       Jongieux, 73170    3.0
# 10                          Hakuba          Paris, 75001    2.0
# 11                        Le Corot  Ville-d'Avray, 92410    2.0
# 23                  L'Abysse Paris          Paris, 75008    2.0
# 26                          Arbane          Reims, 51100    2.0
# 32                   Bulle d'Osier        Langres, 52200    2.0
# 53                 Frédéric Doucet      Charolles, 71120    2.0
# 62                     L'Ambroisie          Paris, 75004    2.0
# 77  La Table de Christophe Dufossé         Busnes, 62350    2.0
# 83                        Alliance          Paris, 75005    2.0
# 91                          Virtus          Paris, 75012    2.0

# %% [markdown]
# It was [announced in the press](https://guide.michelin.com/gb/en/article/news-and-views/all-the-winners-in-the-michelin-guide-france-2025) that there are two new 3* and nine new 2*.

# %%
from fuzzywuzzy import process

# Define a threshold for matching
threshold = 70

# Create a function to perform fuzzy matching
def get_matches(new_entry, old_data):
    # Use fuzzywuzzy's process.extract to get matches with a score
    matches = process.extract(new_entry['name'], old_data['name'], scorer=fuzz.token_set_ratio, limit=None)

    # Filter matches based on a threshold score
    high_score_matches = [match for match in matches if match[1] >= threshold]
    return high_score_matches

# %%
# Apply fuzzy matching to the new high-star restaurants
new_high_stars['matches_in_24'] = new_high_stars.apply(lambda x: get_matches(x, france_24), axis=1)

# %%
# Display results
new_high_stars[['name', 'location', 'stars', 'matches_in_24']]
# Out:
#                                                  name  \
# 5                              Christopher Coutanceau
# 21                                      Le Coquillage
# 11                                  La Table des Amis
# 20                                      Cédric Burtin
# 24                                    Sushi Yoshinaga
# 33                                              Blanc
# 34                                      Georges Blanc
# 43                          L'Observatoire du Gabriel
# 56  L'Auberge de Saint-Rémy - Fanny Rey & Jonathan...
# 63                                            Ekaitza
# 71                                    Baumanière 1850
# 77                                               Rozó
# 80                                    Maison Nouvelle
#
#                          location  stars  \
# 5              La Rochelle, 17000    3.0
# 21  Saint-Méloir-des-Ondes, 35350    3.0
# 11                Bonnieux, 84480    2.0
# 20              Saint-Rémy, 71100    2.0
# 24                   Paris, 75002    2.0
# 33                   Paris, 75116    2.0
# 34                  Vonnas, 01540    2.0
# 43                Bordeaux, 33000    2.0
# 56  Saint-Rémy-de-Provence, 13210    2.0
# 63                 Ciboure, 64500    2.0
# 71              Courchevel, 73120    2.0
# 77         Marcq-en-Barœul, 59700    2.0
# 80                Bordeaux, 33000    2.0
#
#                                         matches_in_24
# 5                 [(Christopher Coutanceau, 100, 88)]
# 21  [(Le Coquillage, 100, 96), (Le Cottage, 70, 920)]
# 11  [(La Table des Amis by Christophe Bacquié, 100...
# 20                                                 []
# 24  [(Sushi Yoshinaga, 100, 554), (Sushi B, 83, 386)]
# 33  [(Plénitude - Cheval Blanc Paris, 100, 1), (La...
# 34  [(Georges Blanc, 100, 24), (Blanc, 100, 593), ...
# 43            [(L'Observatoire du Gabriel, 100, 451)]
# 56  [(L'Auberge de Saint-Rémy - Fanny Rey & Jonath...
# 63                              [(Ekaitza, 100, 195)]
# 71  [(Baumanière 1850, 100, 596), (L'Oustau de Bau...
# 77                                 [(Rozó, 100, 217)]
# 80  [(Maison Nouvelle, 100, 139), (La Nouvelle Aub...

# %% [markdown]
# "Blanc", `index 33` is a false fuzzy-match so we skip

# %%
# Create a function to perform fuzzy matching and return the best match above the threshold
def get_best_match(new_entry, old_data):
    # Get all top matches
    matches = process.extract(new_entry['name'], old_data['name'], scorer=fuzz.token_set_ratio, limit=10)

    for name, score, index in matches:
        # If the score is perfect and it's an exact name match, use it immediately
        if score == 100 and name.strip().lower() == new_entry['name'].strip().lower():
            return (name, old_data.iloc[index]['location']), score, old_data.iloc[index]['stars']

    # Otherwise, return the top match if score passes threshold
    best_match, score, index = matches[0]
    if score >= threshold:
        return (old_data.iloc[index]['name'], old_data.iloc[index]['location']), score, old_data.iloc[index]['stars']
    else:
        return None, None, None

# %%
# Apply fuzzy matching to the new high-star restaurants
new_high_stars[['best_match_24', 'match_score_24', 'stars_24']] = new_high_stars.apply(
    lambda x: get_best_match(x, france_24),
    axis=1, result_type='expand'
)

# Display results
new_high_stars[['name', 'location', 'stars', 'stars_24', 'best_match_24']]
# Out:
#                                                  name  \
# 5                              Christopher Coutanceau
# 21                                      Le Coquillage
# 11                                  La Table des Amis
# 20                                      Cédric Burtin
# 24                                    Sushi Yoshinaga
# 33                                              Blanc
# 34                                      Georges Blanc
# 43                          L'Observatoire du Gabriel
# 56  L'Auberge de Saint-Rémy - Fanny Rey & Jonathan...
# 63                                            Ekaitza
# 71                                    Baumanière 1850
# 77                                               Rozó
# 80                                    Maison Nouvelle
#
#                          location  stars  stars_24  \
# 5              La Rochelle, 17000    3.0       2.0
# 21  Saint-Méloir-des-Ondes, 35350    3.0       2.0
# 11                Bonnieux, 84480    2.0       2.0
# 20              Saint-Rémy, 71100    2.0       NaN
# 24                   Paris, 75002    2.0       1.0
# 33                   Paris, 75116    2.0       1.0
# 34                  Vonnas, 01540    2.0       3.0
# 43                Bordeaux, 33000    2.0       1.0
# 56  Saint-Rémy-de-Provence, 13210    2.0       1.0
# 63                 Ciboure, 64500    2.0       1.0
# 71              Courchevel, 73120    2.0       1.0
# 77         Marcq-en-Barœul, 59700    2.0       1.0
# 80                Bordeaux, 33000    2.0       1.0
#
#                                         best_match_24
# 5        (Christopher Coutanceau, La Rochelle, 17000)
# 21     (Le Coquillage, Saint-Méloir-des-Ondes, 35350)
# 11  (La Table des Amis by Christophe Bacquié, Bonn...
# 20                                               None
# 24                    (Sushi Yoshinaga, Paris, 75002)
# 33                              (Blanc, Paris, 75116)
# 34                     (Georges Blanc, Vonnas, 01540)
# 43       (L'Observatoire du Gabriel, Bordeaux, 33000)
# 56  (L'Auberge de Saint-Rémy - Fanny Rey & Jonatha...
# 63                          (Ekaitza, Ciboure, 64500)
# 71               (Baumanière 1850, Courchevel, 73120)
# 77                     (Rozó, Marcq-en-Barœul, 59700)
# 80                 (Maison Nouvelle, Bordeaux, 33000)

# %% [markdown]
# We define a function to return the status of the restaurant after inspection of the above df

# %%
# Define a function to determine the status of the restaurant
def determine_status(row):
    # Extract the postal code from the location and best_match_23
    postal_code = row['location'].split(', ')[-1]
    match_postal_code = row['best_match_24'][1].split(', ')[-1] if row['best_match_24'] else None

    # Check if the postal codes match
    if postal_code != match_postal_code:
        return 'new award'
    else:
        # Check for promotion or demotion
        if row['stars_24'] and row['stars']:
            if row['stars_24'] < row['stars']:
                return 'promoted'
            elif row['stars_24'] > row['stars']:
                return 'demoted'
        # If stars are the same or no match, return None (for removal)
        return None

# %%
# Cast 'stars_24' to object
new_high_stars['stars_24'] = new_high_stars['stars_24'].astype('object')
# Apply the function to each row in the DataFrame
new_high_stars['status'] = new_high_stars.apply(determine_status, axis=1)

# update the 'stars_23' based on the status
new_high_stars.loc[new_high_stars['status'] == 'new award', 'stars_24'] = 'New Entry'

# Remove the rows where the status is None (meaning no change in stars)
new_high_stars = new_high_stars.dropna(subset=['status'])

# Display the updated DataFrame
major_star_changes = new_high_stars[['name', 'location', 'stars', 'stars_24', 'status']]

# %%
major_star_changes
# Out:
#                                                  name  \
# 5                              Christopher Coutanceau
# 21                                      Le Coquillage
# 20                                      Cédric Burtin
# 24                                    Sushi Yoshinaga
# 33                                              Blanc
# 34                                      Georges Blanc
# 43                          L'Observatoire du Gabriel
# 56  L'Auberge de Saint-Rémy - Fanny Rey & Jonathan...
# 63                                            Ekaitza
# 71                                    Baumanière 1850
# 77                                               Rozó
# 80                                    Maison Nouvelle
#
#                          location  stars   stars_24     status
# 5              La Rochelle, 17000    3.0        2.0   promoted
# 21  Saint-Méloir-des-Ondes, 35350    3.0        2.0   promoted
# 20              Saint-Rémy, 71100    2.0  New Entry  new award
# 24                   Paris, 75002    2.0        1.0   promoted
# 33                   Paris, 75116    2.0        1.0   promoted
# 34                  Vonnas, 01540    2.0        3.0    demoted
# 43                Bordeaux, 33000    2.0        1.0   promoted
# 56  Saint-Rémy-de-Provence, 13210    2.0        1.0   promoted
# 63                 Ciboure, 64500    2.0        1.0   promoted
# 71              Courchevel, 73120    2.0        1.0   promoted
# 77         Marcq-en-Barœul, 59700    2.0        1.0   promoted
# 80                Bordeaux, 33000    2.0        1.0   promoted

# %%
# We manually write the demotion of Le Puits Saint Jacques to star_changes
puits_StJ = star_changes.loc[49]
puits_StJ
# Out:
# name                     Le Puits Saint Jacques
# address_25              57 avenue Victor-Capoul
# location                       Pujaudran, 32600
# url           http://www.lepuitssaintjacques.fr
# stars_24                                    2.0
# stars_25                                    1.0
# Name: 49, dtype: object

# %%
data_to_append = {
    'name': puits_StJ['name'],
    'location': puits_StJ['location'],
    'stars': puits_StJ['stars_25'],
    'stars_24': puits_StJ['stars_24'],
    'status': 'demoted'
}

row_to_append = pd.DataFrame([data_to_append])
major_star_changes = pd.concat([major_star_changes, row_to_append], ignore_index=True)

# %%
major_star_changes
# Out:
#                                                  name  \
# 0                              Christopher Coutanceau
# 1                                       Le Coquillage
# 2                                       Cédric Burtin
# 3                                     Sushi Yoshinaga
# 4                                               Blanc
# 5                                       Georges Blanc
# 6                           L'Observatoire du Gabriel
# 7   L'Auberge de Saint-Rémy - Fanny Rey & Jonathan...
# 8                                             Ekaitza
# 9                                     Baumanière 1850
# 10                                               Rozó
# 11                                    Maison Nouvelle
# 12                             Le Puits Saint Jacques
#
#                          location  stars   stars_24     status
# 0              La Rochelle, 17000    3.0        2.0   promoted
# 1   Saint-Méloir-des-Ondes, 35350    3.0        2.0   promoted
# 2               Saint-Rémy, 71100    2.0  New Entry  new award
# 3                    Paris, 75002    2.0        1.0   promoted
# 4                    Paris, 75116    2.0        1.0   promoted
# 5                   Vonnas, 01540    2.0        3.0    demoted
# 6                 Bordeaux, 33000    2.0        1.0   promoted
# 7   Saint-Rémy-de-Provence, 13210    2.0        1.0   promoted
# 8                  Ciboure, 64500    2.0        1.0   promoted
# 9               Courchevel, 73120    2.0        1.0   promoted
# 10         Marcq-en-Barœul, 59700    2.0        1.0   promoted
# 11                Bordeaux, 33000    2.0        1.0   promoted
# 12               Pujaudran, 32600    1.0        2.0    demoted

# %% [markdown]
# ----
# &nbsp;
# ### Merging the promotions/demotions with `france_25`

# %%
france_25.head()
# Out:
#              name                                       address  \
# 0     L'Ambroisie                            9 place des Vosges
# 1  Flocons de Sel               1775 route du Leutaz, Le Leutaz
# 2         Épicure  Le Bristol, 112 rue du Faubourg-Saint-Honoré
# 3          Arpège                             84 rue de Varenne
# 4  Le Pré Catelan          Route de Suresnes - bois de Boulogne
#
#         location        arrondissement department_num    department capital  \
# 0   Paris, 75004  4th (Hôtel-de-Ville)             75         Paris   Paris
# 1  Megève, 74120            Bonneville             74  Haute-Savoie  Annecy
# 2   Paris, 75008          8th (Élysée)             75         Paris   Paris
# 3   Paris, 75007  7th (Palais-Bourbon)             75         Paris   Paris
# 4   Paris, 75016          16th (Passy)             75         Paris   Paris
#
#                  region price                 cuisine  \
# 0         Île-de-France  €€€€         Classic Cuisine
# 1  Auvergne-Rhône-Alpes  €€€€          Modern Cuisine
# 2         Île-de-France  €€€€          Modern Cuisine
# 3         Île-de-France  €€€€                Creative
# 4         Île-de-France  €€€€  Creative, Contemporary
#
#                                                  url    award  stars  \
# 0                   https://www.ambroisie-paris.com/  3 Stars    3.0
# 1                       https://www.floconsdesel.com  3 Stars    3.0
# 2  https://www.oetkercollection.com/fr/hotels/le-...  3 Stars    3.0
# 3                     https://www.alain-passard.com/  3 Stars    3.0
# 4                      https://www.leprecatelan.com/  3 Stars    3.0
#
#    greenstar  longitude   latitude
# 0          0   2.364521  48.855494
# 1          0   6.596963  45.830240
# 2          0   2.314598  48.871722
# 3          1   2.317013  48.855754
# 4          0   2.250718  48.863937

# %%
# Merge major_star_changes with france_24 on 'name' and 'location'
merged_changes = pd.merge(major_star_changes, france_25, on=['name', 'location'], how='left')

merged_changes.rename(columns={'stars_y': 'stars'}, inplace=True)
column_order = ['name', 'address', 'location', 'arrondissement', 'department_num', 'department', 'capital', 'region',
       'price', 'cuisine', 'url', 'award', 'stars', 'stars_24', 'status', 'longitude', 'latitude']
merged_changes = merged_changes[column_order]

# %%
merged_changes
# Out:
#                                                  name  \
# 0                              Christopher Coutanceau
# 1                                       Le Coquillage
# 2                                       Cédric Burtin
# 3                                     Sushi Yoshinaga
# 4                                               Blanc
# 5                                       Georges Blanc
# 6                           L'Observatoire du Gabriel
# 7   L'Auberge de Saint-Rémy - Fanny Rey & Jonathan...
# 8                                             Ekaitza
# 9                                     Baumanière 1850
# 10                                               Rozó
# 11                                    Maison Nouvelle
# 12                             Le Puits Saint Jacques
#
#                                            address  \
# 0                          Plage de la Concurrence
# 1                                 Lieu-dit Le Buot
# 2                               Chemin de Martorez
# 3                            27 rue du 4-Septembre
# 4                              52 rue de Longchamp
# 5                                  Place du Marché
# 6                            10 place de la Bourse
# 7                            12 boulevard Mirabeau
# 8                            15 quai Maurice-Ravel
# 9   Le Strato, Route de Bellecôte, Courchevel 1850
# 10                           34 rue Raymond-Derain
# 11                                     11 rue Rode
# 12                         57 avenue Victor-Capoul
#
#                          location    arrondissement department_num  \
# 0              La Rochelle, 17000       La Rochelle             17
# 1   Saint-Méloir-des-Ondes, 35350        Saint-Malo             35
# 2               Saint-Rémy, 71100  Chalon-sur-Saône             71
# 3                    Paris, 75002      2nd (Bourse)             75
# 4                    Paris, 75116      16th (Passy)             75
# 5                   Vonnas, 01540   Bourg-en-Bresse             01
# 6                 Bordeaux, 33000          Bordeaux             33
# 7   Saint-Rémy-de-Provence, 13210             Arles             13
# 8                  Ciboure, 64500           Bayonne             64
# 9               Courchevel, 73120       Albertville             73
# 10         Marcq-en-Barœul, 59700             Lille             59
# 11                Bordeaux, 33000          Bordeaux             33
# 12               Pujaudran, 32600              Auch             32
#
#               department          capital                      region price  \
# 0      Charente-Maritime      La Rochelle          Nouvelle-Aquitaine  €€€€
# 1        Ille-et-Vilaine           Rennes                    Bretagne  €€€€
# 2         Saône-et-Loire            Mâcon     Bourgogne-Franche-Comté  €€€€
# 3                  Paris            Paris               Île-de-France  €€€€
# 4                  Paris            Paris               Île-de-France  €€€€
# 5                    Ain  Bourg-en-Bresse        Auvergne-Rhône-Alpes  €€€€
# 6                Gironde         Bordeaux          Nouvelle-Aquitaine  €€€€
# 7       Bouches-du-Rhône        Marseille  Provence-Alpes-Côte d'Azur  €€€€
# 8   Pyrénées-Atlantiques              Pau          Nouvelle-Aquitaine   €€€
# 9                 Savoie         Chambéry        Auvergne-Rhône-Alpes  €€€€
# 10                  Nord            Lille             Hauts-de-France  €€€€
# 11               Gironde         Bordeaux          Nouvelle-Aquitaine  €€€€
# 12                  Gers             Auch                   Occitanie  €€€€
#
#                      cuisine  \
# 0    Seafood, Modern Cuisine
# 1          Creative, Seafood
# 2   Creative, Modern Cuisine
# 3                   Japanese
# 4                   Creative
# 5            Classic Cuisine
# 6   Modern Cuisine, Creative
# 7             Modern Cuisine
# 8   Creative, Modern Cuisine
# 9                   Creative
# 10  Creative, Modern Cuisine
# 11            Modern Cuisine
# 12            Modern Cuisine
#
#                                                   url    award  stars  \
# 0            http://www.christophercoutanceau.com/fr/  3 Stars    3.0
# 1   https://www.maisons-de-bricourt.com/fr/page/le...  3 Stars    3.0
# 2                        https://cedricburtin.com/fr/  2 Stars    2.0
# 3                       http://www.sushiyoshinaga.com  2 Stars    2.0
# 4                            https://blanc-paris.com/  2 Stars    2.0
# 5                    https://www.georgesblanc.com/fr/  2 Stars    2.0
# 6                      https://le-gabriel-bordeaux.fr  2 Stars    2.0
# 7                https://www.aubergesaintremy.com/fr/  2 Stars    2.0
# 8                  https://www.restaurant-ekaitza.fr/  2 Stars    2.0
# 9                        https://www.hotelstrato.com/  2 Stars    2.0
# 10                      http://www.restaurant-rozo.fr  2 Stars    2.0
# 11                      http://www.maison-nouvelle.fr  2 Stars    2.0
# 12                  http://www.lepuitssaintjacques.fr   1 Star    1.0
#
#      stars_24     status  longitude   latitude
# 0         2.0   promoted  -1.159918  46.155363
# 1         2.0   promoted  -1.871123  48.643065
# 2   New Entry  new award   4.820027  46.756771
# 3         1.0   promoted   2.334956  48.869838
# 4         1.0   promoted   2.287481  48.865117
# 5         3.0    demoted   4.989499  46.220108
# 6         1.0   promoted  -0.570715  44.841350
# 7         1.0   promoted   4.833321  43.788561
# 8         1.0   promoted  -1.667464  43.385259
# 9         1.0   promoted   6.638078  45.410293
# 10        1.0   promoted   3.090952  50.675200
# 11        1.0   promoted  -0.572138  44.852480
# 12        2.0    demoted   1.149996  43.590729

# %% [markdown]
# ----
# &nbsp;
# ## Changes in the michelin guide

# %%
stars_24 = france_24[france_24['stars'] >= 1]
stars_25 = france_25[france_25['stars'] >= 1]

# %%
# Count the occurrences of each star in france_23 and france_24
stars_count_24 = stars_24.groupby('stars').size()
stars_count_25 = stars_25.groupby('stars').size()

# Ensure all possible star values are represented, even if there are no restaurants with that count
star_ratings = [1, 2, 3]
stars_count_24 = stars_count_24.reindex(star_ratings)
stars_count_25 = stars_count_25.reindex(star_ratings)

# Create a DataFrame to display the counts side by side
star_comparison_table = pd.DataFrame({
    'Star Rating': star_ratings,
    '2024 Guide': stars_count_24.values,
    '2025 Guide': stars_count_25.values
})

# Display the table
star_comparison_table
# Out:
#    Star Rating  2024 Guide  2025 Guide
# 0            1         530         538
# 1            2          73          78
# 2            3          29          30

# %% [markdown]
# ----
# &nbsp;
# ## New restaurants by region

# %%
# Function import
from Functions.functions_visualisation import top_restaurants

# %%
top_restaurants(merged_changes, granularity='region', star_rating=3, top_n=5)
# Out:
# Only 2 unique regions found.
#
# Top 2 regions with most ⭐⭐⭐ restaurants:
#
#
# Region: Bretagne
# 1 ⭐⭐⭐ Restaurant
# <br>Restaurant: <a href='https://www.maisons-de-bricourt.com/fr/page/le-coquillage' target='_blank'>Le Coquillage</a><br>Address: Lieu-dit Le Buot<br>Location: Saint-Méloir-des-Ondes, 35350<br>Style of Cuisine: Creative, Seafood<br>Price: €€€€<br><br>
# Region: Nouvelle-Aquitaine
# 1 ⭐⭐⭐ Restaurant
# <br>Restaurant: <a href='http://www.christophercoutanceau.com/fr/' target='_blank'>Christopher Coutanceau</a><br>Address: Plage de la Concurrence<br>Location: La Rochelle, 17000<br>Style of Cuisine: Seafood, Modern Cuisine<br>Price: €€€€<br><br>

# %%
top_restaurants(merged_changes, granularity='region', star_rating=2, top_n=5)
# Out:
# Top 5 regions with most ⭐⭐ restaurants:
#
#
# Region: Nouvelle-Aquitaine
# 3 ⭐⭐ Restaurants
# <br>Restaurant: <a href='https://le-gabriel-bordeaux.fr' target='_blank'>L'Observatoire du Gabriel</a><br>Address: 10 place de la Bourse<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine, Creative<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.restaurant-ekaitza.fr/' target='_blank'>Ekaitza</a><br>Address: 15 quai Maurice-Ravel<br>Location: Ciboure, 64500<br>Style of Cuisine: Creative, Modern Cuisine<br>Price: €€€<br><br>
# <br>Restaurant: <a href='http://www.maison-nouvelle.fr' target='_blank'>Maison Nouvelle</a><br>Address: 11 rue Rode<br>Location: Bordeaux, 33000<br>Style of Cuisine: Modern Cuisine<br>Price: €€€€<br><br>
# Region: Auvergne-Rhône-Alpes
# 2 ⭐⭐ Restaurants
# <br>Restaurant: <a href='https://www.georgesblanc.com/fr/' target='_blank'>Georges Blanc</a><br>Address: Place du Marché<br>Location: Vonnas, 01540<br>Style of Cuisine: Classic Cuisine<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://www.hotelstrato.com/' target='_blank'>Baumanière 1850</a><br>Address: Le Strato, Route de Bellecôte, Courchevel 1850<br>Location: Courchevel, 73120<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# Region: Île-de-France
# 2 ⭐⭐ Restaurants
# <br>Restaurant: <a href='http://www.sushiyoshinaga.com' target='_blank'>Sushi Yoshinaga</a><br>Address: 27 rue du 4-Septembre<br>Location: Paris, 75002<br>Style of Cuisine: Japanese<br>Price: €€€€<br><br>
# <br>Restaurant: <a href='https://blanc-paris.com/' target='_blank'>Blanc</a><br>Address: 52 rue de Longchamp<br>Location: Paris, 75116<br>Style of Cuisine: Creative<br>Price: €€€€<br><br>
# Region: Bourgogne-Franche-Comté
# 1 ⭐⭐ Restaurant
# <br>Restaurant: <a href='https://cedricburtin.com/fr/' target='_blank'>Cédric Burtin</a><br>Address: Chemin de Martorez<br>Location: Saint-Rémy, 71100<br>Style of Cuisine: Creative, Modern Cuisine<br>Price: €€€€<br><br>
# Region: Hauts-de-France
# 1 ⭐⭐ Restaurant
# <br>Restaurant: <a href='http://www.restaurant-rozo.fr' target='_blank'>Rozó</a><br>Address: 34 rue Raymond-Derain<br>Location: Marcq-en-Barœul, 59700<br>Style of Cuisine: Creative, Modern Cuisine<br>Price: €€€€<br><br>

# %% [markdown]
# ----
# &nbsp;
# ## Postscript - Useful code
# Searching for particular restaurants - Verify the differences

# %%
# Function to find potential matches based on the restaurant name
def find_potential_matches(search_name, df, threshold=70):
    # Use fuzzy matching to find potential matches and their scores
    potential_matches = process.extract(search_name, df['name'], scorer=fuzz.token_set_ratio)
    
    # Filter out matches that meet or exceed the threshold score
    good_matches = [(match[0], match[1]) for match in potential_matches if match[1] >= threshold]
    return good_matches

# %%
# The name of the restaurant you're interested in
search_name = "Le Coquillage"

# %%
# Use the function to find matches in france_23
matches_in_24 = find_potential_matches(search_name, france_24, threshold)

# Use the function to find matches in france_24
matches_in_25 = find_potential_matches(search_name, france_25, threshold)

# Display the results
print("Potential matches in 2024 data:")
for match in matches_in_24:
    print(f"Name: {match[0]}, Score: {match[1]}")

print("\nPotential matches in 2025 data:")
for match in matches_in_25:
    print(f"Name: {match[0]}, Score: {match[1]}")
# Out:
# Potential matches in 2024 data:
# Name: Le Coquillage, Score: 100
# Name: Le Cottage, Score: 70
#
# Potential matches in 2025 data:
# Name: Le Coquillage, Score: 100
# Name: Le Collet, Score: 73
# Name: La Courtille, Score: 72
# Name: Le Cottage, Score: 70

# %% [markdown]
# ----
